# %%
import pandas as pd

# %%
df = pd.read_csv('서울시 병의원 위치 정보.csv')
df
# Out:
#            기관ID                                                 주소 병원분류 병원분류명  \
# 0      B1100027                           서울특별시 강남구 봉은사로 612 (삼성동)    E  한방병원
# 1      A1123763  서울특별시 강서구 양천로 424 가양역 데시앙플렉스 지식산업센터 2층 236~240...    C    의원
# 2      A1110933              서울특별시 강남구 선릉로 660 (삼성동 브라운스톤레전드 304호)    N  치과의원
# 3      A1116812         서울특별시 서초구 강남대로 355 삼성화재 서초사옥 181920층 (서초동)    C    의원
# 4      A1106574                 서울특별시 강남구 테헤란로 139-1 2층 지하1층 (역삼동)    C    의원
# ...         ...                                                ...  ...   ...
# 19052  A1103025                           서울특별시 강서구 곰달래로 223 (화곡동)    C    의원
# 19053  B1101664                   서울특별시 용산구 한강대로 109 (한강로2가 용성비즈텔)    G   한의원
# 19054  C1108476                서울특별시 강남구 봉은사로 213 센트럴타워 5~8층 (논현동)    E  한방병원
# 19055  C1108345                  서울특별시 강서구 강서로 173 터보빌딩 789층 (화곡동)    E  한방병원
# 19056  A1116520                  서울특별시 은평구 은평로 170 305호 (응암동 상현빌딩)    C    의원
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19057 entries, 0 to 19056
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   기관ID          19057 non-null  object
#  1   주소            19057 non-null  object
#  2   병원분류          19057 non-null  object
#  3   병원분류명         19057 non-null  object
#  4   응급의료기관코드      19057 non-null  object
#  5   응급의료기관코드명     19057 non-null  object
#  6   응급실운영여부(1/2)  19057 non-null  int64
#  7   비고            19029 non-null  object
#  8   기관설명상세        19015 non-null  object
#  9   간이약도          19056 non-null  object
#  10  기관명           19057 non-null  object
#  11  대표전화1         19057 non-null  object
#  12  응급실전화         19032 non-null  object
#  13  진료시간(월요일)C    19057 non-null  int64
#  14  진료시간(화요일)C    19057 non-null  int64
#  15  진료시간(수요일)C    19057 non-null  int64
#  16  진료시간(목요일)C    19057 non-null  int64
#  17  진료시간(금요일)C    19057 non-null  int64
# ...

# %%
pd.set_option('display.max_columns',len(df.columns))
df.head()
# Out:
#        기관ID                                                 주소 병원분류 병원분류명  \
# 0  B1100027                           서울특별시 강남구 봉은사로 612 (삼성동)    E  한방병원
# 1  A1123763  서울특별시 강서구 양천로 424 가양역 데시앙플렉스 지식산업센터 2층 236~240...    C    의원
# 2  A1110933              서울특별시 강남구 선릉로 660 (삼성동 브라운스톤레전드 304호)    N  치과의원
# 3  A1116812         서울특별시 서초구 강남대로 355 삼성화재 서초사옥 181920층 (서초동)    C    의원
# 4  A1106574                 서울특별시 강남구 테헤란로 139-1 2층 지하1층 (역삼동)    C    의원
#
#   응급의료기관코드  응급의료기관코드명  응급실운영여부(1/2)                                 비고  \
# 0     G099  응급의료기관 이외             2  진료과목마다 진료시간 다릅니다. 전화 확인 후 방문해주세요.
# 1     G099  응급의료기관 이외             2                   점심시간 13:00~14:00
# 2     G099  응급의료기관 이외             2         점심 12:30~14:00 토요일 진료 확인요망
# 3     G099  응급의료기관 이외             2                   점심시간 13:00~14:00
# 4     G099  응급의료기관 이외             2                   점심시간 13:00~14:00
#
#                                               기관설명상세  \
# ...

# %%
df['응급실운영여부(1/2)'].unique()
# Out:
# array([2, 1], dtype=int64)
