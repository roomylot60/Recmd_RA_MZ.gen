# %%
import pandas as pd

# %%
df = pd.read_csv('서울시 병원 인허가 정보.csv',engine='python')
pd.set_option('display.max_columns',41)

# %%
df.head()
# Out:
#    개방자치단체코드                       관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3220000  PHMA220223220033021200002  20220228      NaN       1  영업/정상
# 1   3100000  PHMA220223100034021200001  20220224      NaN       1  영업/정상
# 2   3220000  PHMA220223220033021200004  20220808      NaN       1  영업/정상
# 3   3140000  PHMA220193140033021200001  20191213      NaN       1  영업/정상
# 4   3140000  PHMA220063140033021200001  20060810      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자          전화번호  소재지면적  \
# 0        13     영업중   NaN     NaN     NaN    NaN         -2838    NaN
# 1        13     영업중   NaN     NaN     NaN    NaN     1533-7585    NaN
# 2        13     영업중   NaN     NaN     NaN    NaN  02-6203-9000    NaN
# 3        13     영업중   NaN     NaN     NaN    NaN  02-2601-7111    NaN
# 4        13     영업중   NaN     NaN     NaN    NaN  02-1899-2221    NaN
#
#    소재지우편번호                                    지번주소  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   개방자치단체코드   860 non-null    int64
#  1   관리번호       860 non-null    object
#  2   인허가일자      860 non-null    int64
#  3   인허가취소일자    0 non-null      float64
#  4   영업상태코드     860 non-null    int64
#  5   영업상태명      860 non-null    object
#  6   상세영업상태코드   860 non-null    int64
#  7   상세영업상태명    860 non-null    object
#  8   폐업일자       270 non-null    float64
#  9   휴업시작일자     25 non-null     float64
#  10  휴업종료일자     25 non-null     float64
#  11  재개업일자      0 non-null      float64
#  12  전화번호       826 non-null    object
#  13  소재지면적      0 non-null      float64
#  14  소재지우편번호    298 non-null    float64
#  15  지번주소       721 non-null    object
#  16  도로명주소      770 non-null    object
#  17  도로명우편번호    743 non-null    float64
#  18  사업장명       860 non-null    object
# ...

# %%
df.describe().loc[['min','max']]
# Out:
#       개방자치단체코드       인허가일자  인허가취소일자  영업상태코드  상세영업상태코드        폐업일자      휴업시작일자  \
# min  3000000.0  19000101.0      NaN     1.0       2.0  20010713.0  20090202.0
# max  3240000.0  20220927.0      NaN     4.0      24.0  20220921.0  20221001.0
#
#          휴업종료일자  재개업일자  소재지면적   소재지우편번호   도로명우편번호        최종수정일자      좌표정보(X)  \
# min  20090430.0    NaN    NaN  100091.0    1019.0  2.008110e+13  182141.2055
# max  20230731.0    NaN    NaN  158861.0  158861.0  2.022100e+13  215314.7463
#
#          좌표정보(Y)    의료인수   입원실수    병상수        총면적  지정취소일자  완화의료지정형태  \
# min  438879.4251     0.0    0.0    0.0       0.00     NaN       NaN
# max  464003.4051  1406.0  247.0  855.0  176891.01     NaN       NaN
#
#      완화의료담당부서명  구급차특수  구급차일반  총인원  구조사수  허가병상수  최초지정일자
# min        NaN    0.0    0.0  NaN   NaN    0.0     NaN
# max        NaN    0.0    0.0  NaN   NaN    0.0     NaN

# %%
df['영업상태코드'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
df['상세영업상태코드'].unique()
# Out:
# array([13,  3,  2, 24], dtype=int64)
