# %%
import pandas as pd

# %%
df = pd.read_csv('서울시 약국 운영시간 정보.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5315 entries, 0 to 5314
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   약국ID        5315 non-null   object
#  1   주소          5315 non-null   object
#  2   약국명         5315 non-null   object
#  3   대표전화1       5315 non-null   object
#  4   진료시간(월요일)C  5315 non-null   int64
#  5   진료시간(화요일)C  5315 non-null   int64
#  6   진료시간(수요일)C  5315 non-null   int64
#  7   진료시간(목요일)C  5315 non-null   int64
#  8   진료시간(금요일)C  5315 non-null   int64
#  9   진료시간(토요일)C  5315 non-null   int64
#  10  진료시간(일요일)C  5308 non-null   float64
#  11  진료시간(공휴일)C  5308 non-null   float64
#  12  진료시간(월요일)S  5315 non-null   int64
#  13  진료시간(화요일)S  5315 non-null   int64
#  14  진료시간(수요일)S  5315 non-null   int64
#  15  진료시간(목요일)S  5315 non-null   int64
#  16  진료시간(금요일)S  5315 non-null   int64
#  17  진료시간(토요일)S  5315 non-null   int64
#  18  진료시간(일요일)S  5308 non-null   float64
# ...

# %%
pd.set_option('display.max_columns',len(df.columns))
df.head()
# Out:
#        약국ID                                      주소       약국명         대표전화1  \
# 0  C1109587  서울특별시 강남구 헌릉로571길 7 강남레체 1층 101호 (세곡동)  100세건강약국   02-445-1460
# 1  C1104730                   서울특별시 강서구 화곡로 173  1층  21C세계로약국  02-2607-0624
# 2  C1109521           서울특별시 금천구 시흥대로62길 29 1층 (시흥동)  365그랜드약국   02-896-1223
# 3  C1109579  서울특별시 마포구 백범로 199 메트로디오빌빌딩 108호 (신공덕동)   365열린약국  02-6010-2720
# 4  C1109578      서울특별시 강서구 공항대로41길 52 버들빌딩 1층 (등촌동)   365열린약국  02-3661-3650
#
#    진료시간(월요일)C  진료시간(화요일)C  진료시간(수요일)C  진료시간(목요일)C  진료시간(금요일)C  진료시간(토요일)C  \
# 0        2000        2000        2000        2000        2000        1700
# 1        2000        2000        2000        2000        2000        1600
# 2        2130        2130        2130        2130        2130        2130
# 3        2100        2100        2100        2100        2100        1700
# 4        2500        2500        2500        2500        2500        2500
#
# ...

# %%
df.describe()
# Out:
#         진료시간(월요일)C   진료시간(화요일)C   진료시간(수요일)C   진료시간(목요일)C   진료시간(금요일)C  \
# count  5315.000000  5315.000000  5315.000000  5315.000000  5315.000000
# mean   1984.392098  1988.713641  1986.317592  1987.991722  1987.888617
# std     181.670944   159.162930   161.852659   161.133505   159.848164
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1900.000000  1900.000000  1900.000000  1900.000000  1900.000000
# 50%    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# 75%    2100.000000  2100.000000  2100.000000  2100.000000  2100.000000
# max    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
#
#         진료시간(토요일)C   진료시간(일요일)C   진료시간(공휴일)C   진료시간(월요일)S   진료시간(화요일)S  \
# count  5315.000000  5308.000000  5308.000000  5315.000000  5315.000000
# mean   1703.858137  1897.586473  1890.476639   888.809031   890.385701
# std     306.151977   360.009385   359.879042    77.625554    67.712308
# ...

# %%
df['진료시간(월요일)C'].unique()
# Out:
# array([2000, 2130, 2100, 2500, 1930, 1900, 2200, 1830, 2230, 1800, 2030,
#        2300, 2240, 1200, 1730, 2400,    0, 2050, 2210, 1500, 1815, 1810,
#        2250, 1400, 1700, 1840, 2600, 1600,   30,  100, 1850, 1530, 1920,
#        2150,  901, 2359, 2015, 2330, 1300, 1740, 1330, 1950, 1940, 2140,
#        2120, 1820,  130,  300, 1845, 1835, 2345, 1630, 1910, 1430, 2020,
#        2040, 2220, 1715, 3000, 1230, 1000, 2115], dtype=int64)

# %%
df[df['진료시간(월요일)C']==3000]
# Out:
#           약국ID                  주소      약국명        대표전화1  진료시간(월요일)C  \
# 3870  C1104814  서울특별시 강남구 강남대로 478  제일그랜드약국  02-546-0093        3000
#
#       진료시간(화요일)C  진료시간(수요일)C  진료시간(목요일)C  진료시간(금요일)C  진료시간(토요일)C  진료시간(일요일)C  \
# 3870        3000        3000        3000        3000        3000      3000.0
#
#       진료시간(공휴일)C  진료시간(월요일)S  진료시간(화요일)S  진료시간(수요일)S  진료시간(목요일)S  진료시간(금요일)S  \
# 3870      2400.0         600         600         600         600         600
#
#       진료시간(토요일)S  진료시간(일요일)S  진료시간(공휴일)S  우편번호1  우편번호2        병원경도       병원위도  \
# 3870         600       600.0         0.0     61     20  127.024765  37.505177
#
#          작업일시
# 3870  42:16.0

# %%
df['구 구분'] = df['주소'].str.split(" ").str[1]
df
# Out:
#           약국ID                                      주소       약국명  \
# 0     C1109587  서울특별시 강남구 헌릉로571길 7 강남레체 1층 101호 (세곡동)  100세건강약국
# 1     C1104730                   서울특별시 강서구 화곡로 173  1층  21C세계로약국
# 2     C1109521           서울특별시 금천구 시흥대로62길 29 1층 (시흥동)  365그랜드약국
# 3     C1109579  서울특별시 마포구 백범로 199 메트로디오빌빌딩 108호 (신공덕동)   365열린약국
# 4     C1109578      서울특별시 강서구 공항대로41길 52 버들빌딩 1층 (등촌동)   365열린약국
# ...        ...                                     ...       ...
# 5310  C1107687            서울특별시 영등포구 디지털로37길 9-5 (대림동)      힘찬약국
# 5311  C1107751  서울특별시 도봉구 삼양로 580-4 1층 101호 (쌍문동 노스브릭)      힘찬약국
# 5312  C1108162            서울특별시 광진구 뚝섬로 631-1 1층 (자양동)      힘찬약국
# 5313  C1103921    서울특별시 중구 장충단로13길 7 401호 (을지로6가 을호빌딩)      힘찬약국
# 5314  C1104764                     서울특별시 성북구 보국문로 16-1      힘챤약국
#
#              대표전화1  진료시간(월요일)C  진료시간(화요일)C  진료시간(수요일)C  진료시간(목요일)C  \
# 0      02-445-1460        2000        2000        2000        2000
# ...

# %%
df['구 구분'].unique()
# Out:
# array(['강남구', '강서구', '금천구', '마포구', '구로구', '서초구', '강동구', '영등포구', '동작구',
#        '광진구', '강북구', '동대문구', '양천구', '서대문구', '관악구', '성북구', '송파구', '노원구',
#        '은평구', '중구', '도봉구', '종로구', '중랑구', '용산구', '성동구'], dtype=object)

# %%
df.to_csv("Pharmacy_in_Seoul.csv", mode='w')
