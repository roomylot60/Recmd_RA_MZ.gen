# %%
import pandas as pd

# %%
df = pd.read_csv("RB_INDOOR_CLTUR_SPCE_INFO_2020.csv")
pd.set_option('display.max_columns',len(df.columns))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4217 entries, 0 to 4216
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cate_nm        4217 non-null   object
#  1   entrp_nm       4216 non-null   object
#  2   load_addr      4215 non-null   object
#  3   city_do_cd     4197 non-null   float64
#  4   city_gn_gu_cd  4197 non-null   float64
#  5   xpos_lo        4177 non-null   float64
#  6   ypos_la        4177 non-null   float64
#  7   area_nm        4216 non-null   object
#  8   homepage_url   1081 non-null   object
#  9   tel_no         1189 non-null   object
#  10  base_ymd       4217 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 362.5+ KB

# %%
df.head()
# Out:
#   cate_nm entrp_nm                                  load_addr  city_do_cd  \
# 0     오락실    빙고게임장                  강원도 강릉시 강릉대로 269  2층 (교동)        42.0
# 1     오락실    세븐게임장                  강원도 강릉시 강릉대로 272  1층 (교동)        42.0
# 2     오락실  FRIENDS                   강원도 강릉시 강릉대로 422-7 (포남동)        42.0
# 3     오락실     푸쉬푸쉬                     강원도 강릉시 경강로 2076 (임당동)        42.0
# 4     오락실    맥스라이더  강원도 강릉시 경강로 2120 (옥천동  씨네몰  6층 623호 625호)        42.0
#
#    city_gn_gu_cd     xpos_lo    ypos_la area_nm homepage_url tel_no  \
# 0        42150.0  128.898767  37.761699      강원          NaN    NaN
# 1        42150.0  128.899151  37.761524      강원          NaN    NaN
# 2        42150.0  128.910967  37.770876      강원          NaN    NaN
# 3        42150.0  128.894502  37.753406      강원          NaN    NaN
# 4        42150.0  128.898770  37.755391      강원          NaN    NaN
#
#      base_ymd
# 0  2020-12-31
# 1  2020-12-31
# 2  2020-12-31
# 3  2020-12-31
# 4  2020-12-31

# %%
df['load_addr'].str.contains('서울특별시')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4212    False
# 4213    False
# 4214     True
# 4215    False
# 4216    False
# Name: load_addr, Length: 4217, dtype: object

# %%
condition = df['load_addr'].str.contains('서울특별시').fillna(False)
condition
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4212    False
# 4213    False
# 4214     True
# 4215    False
# 4216    False
# Name: load_addr, Length: 4217, dtype: bool

# %%
condition.unique()
# Out:
# array([False,  True])

# %%
df = df[df['load_addr'].str.contains('서울특별시').fillna(False)]
df
# Out:
#      cate_nm          entrp_nm  \
# 2541     볼링장             라인볼링장
# 2542  VR테마파크            VR스테이션
# 2543     오락실            못된 강아지
# 2544  VR테마파크        BAD VR 논현점
# 2545  VR테마파크         콩 VR 강남역점
# ...      ...               ...
# 4179     수영장      국가대표 어린이수영클럽
# 4181     수영장              리틀마린
# 4195     수영장       (주)슈퍼스타시그니쳐
# 4208     수영장       블루오션 키즈 스위밍
# 4214     수영장  (주)슈퍼스타스위밍아카데미마곡
#
#                                               load_addr  city_do_cd  \
# 2541                     서울특별시 강남구 강남대로 308 랜드마크타워 지하2층        11.0
# 2542                    서울특별시 강남구 강남대로 364 미왕빌딩 지하1층~3층        11.0
# 2543                    서울특별시 강남구 강남대로102길 15  1층 (역삼동)        11.0
# 2544                              서울특별시 강남구 강남대로118길 15        11.0
# 2545              서울특별시 강남구 강남대로94길 10 케이스퀘어강남 지하1층 콩VR        11.0
# ...                                                 ...         ...
# 4179            서울특별시 양천구 목동동로 150, 목동 블루스퀘어 지하1층 (신정동)        11.0
# ...

# %%
df['cate_nm'].unique()
# Out:
# array(['볼링장', 'VR테마파크', '오락실', '수영장'], dtype=object)

# %%
df.to_csv("Leisure_in_Seoul.csv", mode='w')
