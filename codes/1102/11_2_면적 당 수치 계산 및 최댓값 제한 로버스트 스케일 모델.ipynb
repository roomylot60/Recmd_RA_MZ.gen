# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.preprocessing import RobustScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA
from yellowbrick.cluster import SilhouetteVisualizer
from scipy.stats import skew, kurtosis

import warnings

warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## 1. 데이터 입력

# %% [markdown]
# ### 1.1 행정동, 밀도 데이터 로드 및 병합

# %%
tmp_df = pd.read_csv('../data/행정동_컬럼추가_최종ver.csv')
pd.set_option('display.max_columns',35)
# tmp_df
tmp_df.rename(columns={'Unnamed: 0':'index'},inplace=True)
tmp_df.set_index('index',inplace=True)

# %%
tmp_df.rename(columns={'인구수':'MZ_NUM'},inplace=True)
tmp_df
# Out:
#         GU   DONG   DONG_CODE  ACADEMY_NUM  KINDER_NUM  FIRE_NUM  ELE_SCH_NUM  \
# index
# 0      종로구  청운효자동  1111051500    18.000000    0.000000       1.0     2.000000
# 1      종로구    사직동  1111053000    19.000000   10.000000       0.0     2.000000
# 2      종로구    삼청동  1111054000     2.000000   10.000000       0.0     0.000000
# 3      종로구    부암동  1111055000    24.000000    0.000000       1.0     4.000000
# 4      종로구    평창동  1111056000    28.000000    0.000000       0.0     0.000000
# ...    ...    ...         ...          ...         ...       ...          ...
# 421    강동구   성내2동  1174065000    63.333333   16.666667       1.0     1.333333
# 422    강동구   성내3동  1174066000    63.333333   16.666667       1.0     1.333333
# 423    강동구     길동  1174068500   100.000000   20.000000       1.0     6.000000
# 424    강동구   둔촌1동  1174069000    38.000000    0.000000       0.0     2.000000
# 425    강동구   둔촌2동  1174070000    38.000000    0.000000       0.0     2.000000
#
#        MID_SCH_NUM  HIGH_SCH_NUM    CCTV_NUM  POLICE_NUM   BIKE_NUM  \
# index
# 0         2.000000           3.0   56.666667    2.000000   5.666667
# 1         0.000000           0.0   41.666667    3.000000  11.666667
# 2         1.000000           1.0   22.000000    1.000000   7.000000
# 3         1.000000           1.0   41.000000    1.000000   5.000000
# 4         0.000000           1.0   21.000000    1.000000   7.000000
# ...            ...           ...         ...         ...        ...
# 421       0.333333           0.0   52.000000    0.333333   6.000000
# 422       0.333333           0.0   52.000000    0.333333   6.000000
# 423       1.000000           0.0  119.000000    0.000000   9.000000
# 424       1.500000           1.0   32.500000    1.000000   5.500000
# 425       1.500000           1.0   32.500000    1.000000   5.500000
#
#        CAR_SHR_NUM  SUBWAY_NUM  SAFE_DLVR_NUM  DPTM_NUM  ANI_HSPT_NUM  \
# index
# 0         1.000000    0.333333       1.000000       0.0      2.000000
# 1         5.000000    1.333333       0.000000       0.0      1.000000
# 2         1.000000    1.000000       0.000000       0.0      0.000000
# 3         5.000000    0.000000       0.000000       0.0      3.000000
# 4         0.000000    0.000000       0.000000       0.0      0.000000
# ...            ...         ...            ...       ...           ...
# 421       6.666667    0.333333       0.666667       0.0      2.666667
# 422       6.666667    0.333333       0.666667       0.0      2.666667
# 423      10.000000    1.000000       1.000000       0.0      8.000000
# 424       2.000000    0.500000       0.000000       0.0      1.500000
# 425       2.000000    0.500000       0.000000       0.0      1.500000
#
#        PHARM_NUM  LEISURE_NUM  KIDS_NUM  SPORT_NUM  GYM_NUM  GOLF_NUM  \
# index
# 0       4.333333     1.000000  0.000000        0.0      0.0  0.000000
# 1      17.333333     1.000000  0.000000        0.0     18.0  3.000000
# 2       2.000000     0.000000  0.000000        1.0      3.0  0.000000
# 3       1.000000     0.000000  0.000000        0.0      2.0  2.000000
# 4       5.000000     0.000000  0.000000        0.0      5.0  5.000000
# ...          ...          ...       ...        ...      ...       ...
# 421    12.666667     1.666667  0.666667        0.0     10.0  4.666667
# 422    12.666667     1.666667  0.666667        0.0     10.0  4.666667
# 423    35.000000     3.000000  1.000000        0.0     18.0  9.000000
# 424    10.000000     0.000000  0.000000        0.0      4.0  3.000000
# 425    10.000000     0.000000  0.000000        0.0      4.0  3.000000
#
#        STARBUCKS_NUM  MC_NUM    CON_NUM  NOISE_VIBRATION_NUM  CHILD_MED_NUM  \
# index
# 0           0.333333     0.0   4.000000         18816.000000       7.333333
# 1           7.333333     0.0  20.000000         22848.000000      10.333333
# 2           1.000000     0.0   2.000000         14112.000000       1.000000
# 3           0.000000     0.0   8.000000          6048.000000       5.000000
# 4           1.000000     0.0   6.000000          4032.000000      10.000000
# ...              ...     ...        ...                  ...            ...
# 421         1.333333     0.0  38.666667          1442.333333       4.000000
# 422         1.333333     0.0  38.666667          1442.333333       4.000000
# 423         2.000000     0.0  76.000000          4327.000000      10.000000
# 424         0.000000     0.5  17.000000          2163.500000       0.000000
# 425         0.000000     0.5  17.000000          2163.500000       0.000000
#
#          CAFE_NUM  PARK_NUM  HOSPITAL_NUM  BUS_CNT  RETAIL_NUM  COLIVING_NUM  \
# index
# 0       39.666667  1.666667     11.666667     14.0    0.000000           0.0
# 1      100.666667  2.666667     74.666667     16.0    2.000000           1.0
# 2       52.000000  1.000000      7.000000     11.0    0.000000           0.0
# 3       30.000000  1.000000      4.000000      9.0    0.000000           0.0
# 4       36.000000  0.000000     14.000000     37.0    0.000000           0.0
# ...           ...       ...           ...      ...         ...           ...
# 421     47.666667  0.000000     59.333333     11.0    3.333333           0.0
# 422     47.666667  0.000000     59.333333      9.0    3.333333           0.0
# 423     63.000000  1.000000    120.000000     28.0    8.000000           0.0
# 424     17.500000  1.000000     14.500000      4.0    0.000000           0.0
# 425     17.500000  1.000000     14.500000     20.0    0.000000           0.0
#
#        MZ_NUM
# index
# 0        3210
# 1        2749
# 2         684
# 3        2585
# 4        4597
# ...       ...
# 421      8130
# 422      7120
# 423     14486
# 424        33
# 425      7001
#
# [426 rows x 35 columns]

# %%
tmp_df.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'ACADEMY_NUM', 'KINDER_NUM', 'FIRE_NUM',
#        'ELE_SCH_NUM', 'MID_SCH_NUM', 'HIGH_SCH_NUM', 'CCTV_NUM', 'POLICE_NUM',
#        'BIKE_NUM', 'CAR_SHR_NUM', 'SUBWAY_NUM', 'SAFE_DLVR_NUM', 'DPTM_NUM',
#        'ANI_HSPT_NUM', 'PHARM_NUM', 'LEISURE_NUM', 'KIDS_NUM', 'SPORT_NUM',
#        'GYM_NUM', 'GOLF_NUM', 'STARBUCKS_NUM', 'MC_NUM', 'CON_NUM',
#        'NOISE_VIBRATION_NUM', 'CHILD_MED_NUM', 'CAFE_NUM', 'PARK_NUM',
#        'HOSPITAL_NUM', 'BUS_CNT', 'RETAIL_NUM', 'COLIVING_NUM', 'MZ_NUM'],
#       dtype='object')

# %%
density_df = pd.read_excel('../data/인구밀도.xlsx')
density_df
# Out:
#       GU  DONG    POP  AREA  DENSITY
# 0    종로구   사직동   9636  1.23     7834
# 1    종로구   삼청동   2739  1.49     1838
# 2    종로구   부암동   9782  2.27     4309
# 3    종로구   평창동  18329  8.87     2066
# 4    종로구   무악동   8297  0.36    23047
# ..   ...   ...    ...   ...      ...
# 421  강동구  천호2동  33753  1.57    21499
# 422  강동구    길동  45973  2.17    21186
# 423  강동구   강일동  32982  2.26    14594
# 424  강동구  상일1동  38929  2.65    14690
# 425  강동구  상일2동  10200  0.54    18889
#
# [426 rows x 5 columns]

# %%
density_df

# %% [markdown]
# ### 1.2 피처 별 가중치 부여 및 통합

# %% [markdown]
# ### 분류 가중치 비율
# - 교통 : 자전거 : 버스 : 지하철 = 0.06 : 0.93 : 1
# - 치안 : 안심택배 제외 나머지 합산
# - 건강 : 병원 : 약국 = 0.94 : 0.06
# - 편의 :
# - 교육 : 공교육(초,중,고) : 사교육(학원) = 1(0.9 : 0.07 : 0.03) : 0.7
# - 육아 : 합산

# %%
# 행정동 데이터, 밀도 데이터 병합
tmp = pd.merge(tmp_df, density_df)

# 컬럼 순서 정렬
tmp = tmp[['GU','DONG','DONG_CODE','POP','AREA','DENSITY',\
           'SUBWAY_NUM','BUS_CNT','BIKE_NUM',\
           'POLICE_NUM','FIRE_NUM','CCTV_NUM',\
           'HOSPITAL_NUM','PHARM_NUM',\
           'DPTM_NUM','RETAIL_NUM','CON_NUM','CAFE_NUM',\
           'ELE_SCH_NUM','MID_SCH_NUM','HIGH_SCH_NUM','ACADEMY_NUM',\
           'KINDER_NUM','CHILD_MED_NUM',\
           'MZ_NUM','COLIVING_NUM','KIDS_NUM','STARBUCKS_NUM','MC_NUM','NOISE_VIBRATION_NUM','SAFE_DLVR_NUM','LEISURE_NUM','SPORT_NUM','GYM_NUM','GOLF_NUM','CAR_SHR_NUM','ANI_HSPT_NUM']]
tmp
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  SUBWAY_NUM  BUS_CNT  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738    0.333333     14.0
# 1    종로구    사직동  1111053000   9636  1.23     7834    1.333333     16.0
# 2    종로구    삼청동  1111054000   2739  1.49     1838    1.000000     11.0
# 3    종로구    부암동  1111055000   9782  2.27     4309    0.000000      9.0
# 4    종로구    평창동  1111056000  18329  8.87     2066    0.000000     37.0
# ..   ...    ...         ...    ...   ...      ...         ...      ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979    0.333333     11.0
# 422  강동구   성내3동  1174066000  23346  0.71    32882    0.333333      9.0
# 423  강동구     길동  1174068500  45973  2.17    21186    1.000000     28.0
# 424  강동구   둔촌1동  1174069000    144  0.92      157    0.500000      4.0
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291    0.500000     20.0
#
#       BIKE_NUM  POLICE_NUM  FIRE_NUM    CCTV_NUM  HOSPITAL_NUM  PHARM_NUM  \
# 0     5.666667    2.000000       1.0   56.666667     11.666667   4.333333
# 1    11.666667    3.000000       0.0   41.666667     74.666667  17.333333
# 2     7.000000    1.000000       0.0   22.000000      7.000000   2.000000
# 3     5.000000    1.000000       1.0   41.000000      4.000000   1.000000
# 4     7.000000    1.000000       0.0   21.000000     14.000000   5.000000
# ..         ...         ...       ...         ...           ...        ...
# 421   6.000000    0.333333       1.0   52.000000     59.333333  12.666667
# 422   6.000000    0.333333       1.0   52.000000     59.333333  12.666667
# 423   9.000000    0.000000       1.0  119.000000    120.000000  35.000000
# 424   5.500000    1.000000       0.0   32.500000     14.500000  10.000000
# 425   5.500000    1.000000       0.0   32.500000     14.500000  10.000000
#
#      DPTM_NUM  RETAIL_NUM    CON_NUM  ...  HIGH_SCH_NUM  ACADEMY_NUM  \
# 0         0.0    0.000000   4.000000  ...           3.0    18.000000
# 1         0.0    2.000000  20.000000  ...           0.0    19.000000
# 2         0.0    0.000000   2.000000  ...           1.0     2.000000
# 3         0.0    0.000000   8.000000  ...           1.0    24.000000
# 4         0.0    0.000000   6.000000  ...           1.0    28.000000
# ..        ...         ...        ...  ...           ...          ...
# 421       0.0    3.333333  38.666667  ...           0.0    63.333333
# 422       0.0    3.333333  38.666667  ...           0.0    63.333333
# 423       0.0    8.000000  76.000000  ...           0.0   100.000000
# 424       0.0    0.000000  17.000000  ...           1.0    38.000000
# 425       0.0    0.000000  17.000000  ...           1.0    38.000000
#
#      KINDER_NUM  CHILD_MED_NUM  MZ_NUM  COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM  \
# 0      0.000000       7.333333    3210           0.0  0.000000       0.333333
# 1     10.000000      10.333333    2749           1.0  0.000000       7.333333
# 2     10.000000       1.000000     684           0.0  0.000000       1.000000
# 3      0.000000       5.000000    2585           0.0  0.000000       0.000000
# 4      0.000000      10.000000    4597           0.0  0.000000       1.000000
# ..          ...            ...     ...           ...       ...            ...
# 421   16.666667       4.000000    8130           0.0  0.666667       1.333333
# 422   16.666667       4.000000    7120           0.0  0.666667       1.333333
# 423   20.000000      10.000000   14486           0.0  1.000000       2.000000
# 424    0.000000       0.000000      33           0.0  0.000000       0.000000
# 425    0.000000       0.000000    7001           0.0  0.000000       0.000000
#
#      MC_NUM  NOISE_VIBRATION_NUM  SAFE_DLVR_NUM  LEISURE_NUM  SPORT_NUM  \
# 0       0.0         18816.000000       1.000000     1.000000        0.0
# 1       0.0         22848.000000       0.000000     1.000000        0.0
# 2       0.0         14112.000000       0.000000     0.000000        1.0
# 3       0.0          6048.000000       0.000000     0.000000        0.0
# 4       0.0          4032.000000       0.000000     0.000000        0.0
# ..      ...                  ...            ...          ...        ...
# 421     0.0          1442.333333       0.666667     1.666667        0.0
# 422     0.0          1442.333333       0.666667     1.666667        0.0
# 423     0.0          4327.000000       1.000000     3.000000        0.0
# 424     0.5          2163.500000       0.000000     0.000000        0.0
# 425     0.5          2163.500000       0.000000     0.000000        0.0
#
#      GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0        0.0  0.000000     1.000000      2.000000
# 1       18.0  3.000000     5.000000      1.000000
# 2        3.0  0.000000     1.000000      0.000000
# 3        2.0  2.000000     5.000000      3.000000
# 4        5.0  5.000000     0.000000      0.000000
# ..       ...       ...          ...           ...
# 421     10.0  4.666667     6.666667      2.666667
# 422     10.0  4.666667     6.666667      2.666667
# 423     18.0  9.000000    10.000000      8.000000
# 424      4.0  3.000000     2.000000      1.500000
# 425      4.0  3.000000     2.000000      1.500000
#
# [426 rows x 37 columns]

# %%
tmp.describe()
# Out:
#           DONG_CODE           POP        AREA       DENSITY  SUBWAY_NUM  \
# count  4.260000e+02    426.000000  426.000000    426.000000  426.000000
# mean   1.143415e+09  22854.523474    1.420728  23150.119718    0.868545
# std    1.920778e+07   9021.822196    1.571263  11326.683743    0.889106
# min    1.111052e+09    144.000000    0.230000    157.000000    0.000000
# 25%    1.126066e+09  16788.500000    0.670000  14512.000000    0.270833
# 50%    1.144064e+09  22141.500000    0.970000  23420.500000    0.666667
# 75%    1.161306e+09  27908.250000    1.487500  31708.500000    1.000000
# max    1.174070e+09  56012.000000   12.680000  55657.000000    6.000000
#
#           BUS_CNT    BIKE_NUM  POLICE_NUM    FIRE_NUM    CCTV_NUM  \
# count  426.000000  426.000000  426.000000  426.000000  426.000000
# mean    15.647887    6.525822    0.565728    0.377934   53.603286
# std      9.956220    4.728339    0.437685    0.568790   41.087587
# min      1.000000    0.833333    0.000000    0.000000    4.333333
# 25%      9.000000    4.000000    0.333333    0.000000   25.946429
# 50%     14.000000    5.500000    0.500000    0.200000   41.375000
# 75%     20.000000    7.400000    0.750000    0.500000   65.731250
# max     79.000000   44.000000    3.500000    4.000000  251.000000
#
#        HOSPITAL_NUM   PHARM_NUM    DPTM_NUM  RETAIL_NUM     CON_NUM  \
# count    426.000000  426.000000  426.000000  426.000000  426.000000
# mean      42.293427   12.169014    0.063380    2.995305   27.239437
# std       35.024099    7.266001    0.207678    2.904085   19.771517
# min        1.000000    1.000000    0.000000    0.000000    0.000000
# 25%       23.500000    8.000000    0.000000    1.333333   17.714286
# 50%       34.500000   11.000000    0.000000    2.400000   22.500000
# 75%       48.000000   14.000000    0.000000    4.000000   29.333333
# max      255.000000   50.000000    1.500000   28.000000  170.000000
#
#          CAFE_NUM  ELE_SCH_NUM  MID_SCH_NUM  HIGH_SCH_NUM  ACADEMY_NUM  \
# count  426.000000   426.000000   426.000000    426.000000   426.000000
# mean    37.985915     2.838028     1.007042      0.809859    57.737089
# std     37.562957     1.465365     0.775321      0.877893    56.280168
# min      2.000000     0.000000     0.000000      0.000000     1.000000
# 25%     19.541667     2.000000     0.500000      0.250000    27.090909
# 50%     27.363636     2.400000     1.000000      0.666667    41.166667
# 75%     39.250000     3.600000     1.400000      1.000000    70.000000
# max    274.000000    10.000000     6.000000      6.500000   480.250000
#
#        KINDER_NUM  CHILD_MED_NUM        MZ_NUM  COLIVING_NUM    KIDS_NUM  \
# count  426.000000     426.000000    426.000000    426.000000  426.000000
# mean    21.572770      14.323944   6970.138498      0.178404    0.518779
# std     18.688217      14.060665   3195.571959      0.590994    0.656479
# min      0.000000       0.000000     33.000000      0.000000    0.000000
# 25%     10.000000       4.381250   4710.250000      0.000000    0.000000
# 50%     20.000000      10.333333   6607.000000      0.000000    0.333333
# 75%     30.000000      18.000000   8666.500000      0.000000    0.729167
# max    170.000000     101.000000  20429.000000      4.000000    4.250000
#
#        STARBUCKS_NUM      MC_NUM  NOISE_VIBRATION_NUM  SAFE_DLVR_NUM  \
# count     426.000000  426.000000           426.000000     426.000000
# mean        1.302817    0.204225          2452.551643       0.622066
# std         2.164240    0.363035          4534.820198       0.503566
# min         0.000000    0.000000           125.750000       0.000000
# 25%         0.333333    0.000000           442.037500       0.000000
# 50%         0.666667    0.000000          1014.000000       0.666667
# 75%         1.333333    0.285714          2163.500000       1.000000
# max        18.500000    4.000000         56112.000000       3.500000
#
#        LEISURE_NUM   SPORT_NUM     GYM_NUM    GOLF_NUM  CAR_SHR_NUM  \
# count   426.000000  426.000000  426.000000  426.000000   426.000000
# mean      1.194836    0.166667    7.448357    3.626761     4.133803
# std       1.606980    0.567719    7.034213    4.318573     3.156750
# min       0.000000    0.000000    0.000000    0.000000     0.000000
# 25%       0.000000    0.000000    3.500000    1.333333     2.285714
# 50%       0.833333    0.000000    6.000000    2.500000     3.500000
# 75%       1.750000    0.000000    9.000000    4.500000     5.000000
# max      15.000000    5.000000   60.000000   32.500000    24.000000
#
#        ANI_HSPT_NUM
# count    426.000000
# mean       2.093897
# std        1.393441
# min        0.000000
# 25%        1.350000
# 50%        2.000000
# 75%        2.500000
# max       12.000000

# %%
# 불필요 컬럼 제거
tmp = tmp.drop(['SPORT_NUM'],axis=1)

# %%
tmp.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'POP', 'AREA', 'DENSITY', 'SUBWAY_NUM',
#        'BUS_CNT', 'BIKE_NUM', 'POLICE_NUM', 'FIRE_NUM', 'CCTV_NUM',
#        'HOSPITAL_NUM', 'PHARM_NUM', 'DPTM_NUM', 'RETAIL_NUM', 'CON_NUM',
#        'CAFE_NUM', 'ELE_SCH_NUM', 'MID_SCH_NUM', 'HIGH_SCH_NUM', 'ACADEMY_NUM',
#        'KINDER_NUM', 'CHILD_MED_NUM', 'MZ_NUM', 'COLIVING_NUM', 'KIDS_NUM',
#        'STARBUCKS_NUM', 'MC_NUM', 'NOISE_VIBRATION_NUM', 'SAFE_DLVR_NUM',
#        'LEISURE_NUM', 'GYM_NUM', 'GOLF_NUM', 'CAR_SHR_NUM', 'ANI_HSPT_NUM'],
#       dtype='object')

# %%
# 피처 통합 함수
def assembling_features(df, weight, name): # 피처들로 구성된 데이터프레임, 피처별 가중치, 새로 생성할 피처의 이름
    columns = df.columns
    values = df[columns].values.tolist()
    sums = []
    
    for i in range(len(df)):
        sigma = 0
        for k in range(len(values[i])):
            sigma += values[i][k] * weight[k]
        sums.append(sigma)
    sum_df = pd.DataFrame(sums,columns=[name])
    return sum_df

# %%
# 합하고자 하는 column 끼리 묶어서 list로 생성
sum_list = [['SUBWAY_NUM','BUS_CNT','BIKE_NUM'],
            ['POLICE_NUM','FIRE_NUM','CCTV_NUM'],
            ['HOSPITAL_NUM','PHARM_NUM'],
            ['DPTM_NUM','RETAIL_NUM','CON_NUM','CAFE_NUM'],
            ['ELE_SCH_NUM','MID_SCH_NUM','HIGH_SCH_NUM','ACADEMY_NUM'],
            ['KINDER_NUM','CHILD_MED_NUM']]
# 각 묶어지는 컬럼 별 가중치 list
weight_list = [[1,0.93,0.06],[1,1,1],[0.94,0.06],[0.04,0.27,0.44,0.25],[0.9,0.07,0.03,0.7],[1,1]]

# 묶어진 column 들의 각각의 column명 list
name_list = ['TRANSPORT','SECURITY','HEALTH','CONVENIENCE','EDUCATION','PARANTING']

# %%
# 큰 카테고리로 묶는 함수
def assembling(df, sum_list, weight_list, name_list): 
    df_tmp = pd.DataFrame(data=range(len(df)))
    for j in range(len(sum_list)):
        tmp_df = df[sum_list[j]]
        name = name_list[j]
        w = weight_list[j]
        sum_df = assembling_features(tmp_df,w,name)

        tmp_df[name_list[j]] = sum_df.values
        tmp_df = tmp_df.drop(sum_list[j],axis=1)
        df_tmp = df_tmp.join(tmp_df)
    del(df_tmp[0])
    return df_tmp

# %%
# 컬럼 끼리 더한 데이터
asmb_df = assembling(tmp,sum_list,weight_list,name_list)
asmb_df
# Out:
#      TRANSPORT    SECURITY      HEALTH  CONVENIENCE  EDUCATION  PARANTING
# 0    13.693333   59.666667   11.226667    11.676667  14.630000   7.333333
# 1    16.913333   44.666667   71.226667    34.506667  15.100000  20.333333
# 2    11.650000   23.000000    6.700000    13.880000   1.500000  11.000000
# 3     8.670000   43.000000    3.820000    11.020000  20.500000   5.000000
# 4    34.830000   22.000000   13.460000    11.640000  19.630000  10.000000
# ..         ...         ...         ...          ...        ...        ...
# 421  10.923333   53.333333   56.533333    29.830000  45.556667  20.666667
# 422   9.063333   53.333333   56.533333    29.830000  45.556667  20.666667
# 423  27.580000  120.000000  114.900000    51.350000  75.470000  30.000000
# 424   4.550000   33.500000   14.230000    11.855000  28.535000   0.000000
# 425  19.430000   33.500000   14.230000    11.855000  28.535000   0.000000
#
# [426 rows x 6 columns]

# %%
# 병합하고 컬럼 순서 재정렬하는 함수
def data_frame_redirect(df, asmb_df, sum_list, name_list):
    for i in range(len(sum_list)):
        df = df.drop(sum_list[i],axis=1)
    df = df.join(asmb_df)
    column_list = ['GU','DONG','DONG_CODE','POP','AREA','DENSITY'] + name_list +['MZ_NUM','COLIVING_NUM','KIDS_NUM','STARBUCKS_NUM','MC_NUM','NOISE_VIBRATION_NUM','LEISURE_NUM','GYM_NUM','GOLF_NUM','CAR_SHR_NUM','ANI_HSPT_NUM']
    df = df[column_list]
    return df

# %%
tmp_df = data_frame_redirect(tmp, asmb_df, sum_list, name_list) # 묶고 묶을 때 사용한 컬럼 제거한 뒤 정리된 데이터 프레임
tmp_df.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'POP', 'AREA', 'DENSITY', 'TRANSPORT',
#        'SECURITY', 'HEALTH', 'CONVENIENCE', 'EDUCATION', 'PARANTING', 'MZ_NUM',
#        'COLIVING_NUM', 'KIDS_NUM', 'STARBUCKS_NUM', 'MC_NUM',
#        'NOISE_VIBRATION_NUM', 'LEISURE_NUM', 'GYM_NUM', 'GOLF_NUM',
#        'CAR_SHR_NUM', 'ANI_HSPT_NUM'],
#       dtype='object')

# %%
tmp_df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT    SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738  13.693333   59.666667
# 1    종로구    사직동  1111053000   9636  1.23     7834  16.913333   44.666667
# 2    종로구    삼청동  1111054000   2739  1.49     1838  11.650000   23.000000
# 3    종로구    부암동  1111055000   9782  2.27     4309   8.670000   43.000000
# 4    종로구    평창동  1111056000  18329  8.87     2066  34.830000   22.000000
# ..   ...    ...         ...    ...   ...      ...        ...         ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979  10.923333   53.333333
# 422  강동구   성내3동  1174066000  23346  0.71    32882   9.063333   53.333333
# 423  강동구     길동  1174068500  45973  2.17    21186  27.580000  120.000000
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.550000   33.500000
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.430000   33.500000
#
#          HEALTH  CONVENIENCE  EDUCATION  PARANTING  MZ_NUM  COLIVING_NUM  \
# 0     11.226667    11.676667  14.630000   7.333333    3210           0.0
# 1     71.226667    34.506667  15.100000  20.333333    2749           1.0
# 2      6.700000    13.880000   1.500000  11.000000     684           0.0
# 3      3.820000    11.020000  20.500000   5.000000    2585           0.0
# 4     13.460000    11.640000  19.630000  10.000000    4597           0.0
# ..          ...          ...        ...        ...     ...           ...
# 421   56.533333    29.830000  45.556667  20.666667    8130           0.0
# 422   56.533333    29.830000  45.556667  20.666667    7120           0.0
# 423  114.900000    51.350000  75.470000  30.000000   14486           0.0
# 424   14.230000    11.855000  28.535000   0.000000      33           0.0
# 425   14.230000    11.855000  28.535000   0.000000    7001           0.0
#
#      KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.333333     0.0         18816.000000     1.000000
# 1    0.000000       7.333333     0.0         22848.000000     1.000000
# 2    0.000000       1.000000     0.0         14112.000000     0.000000
# 3    0.000000       0.000000     0.0          6048.000000     0.000000
# 4    0.000000       1.000000     0.0          4032.000000     0.000000
# ..        ...            ...     ...                  ...          ...
# 421  0.666667       1.333333     0.0          1442.333333     1.666667
# 422  0.666667       1.333333     0.0          1442.333333     1.666667
# 423  1.000000       2.000000     0.0          4327.000000     3.000000
# 424  0.000000       0.000000     0.5          2163.500000     0.000000
# 425  0.000000       0.000000     0.5          2163.500000     0.000000
#
#      GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0        0.0  0.000000     1.000000      2.000000
# 1       18.0  3.000000     5.000000      1.000000
# 2        3.0  0.000000     1.000000      0.000000
# 3        2.0  2.000000     5.000000      3.000000
# 4        5.0  5.000000     0.000000      0.000000
# ..       ...       ...          ...           ...
# 421     10.0  4.666667     6.666667      2.666667
# 422     10.0  4.666667     6.666667      2.666667
# 423     18.0  9.000000    10.000000      8.000000
# 424      4.0  3.000000     2.000000      1.500000
# 425      4.0  3.000000     2.000000      1.500000
#
# [426 rows x 23 columns]

# %%
tmp_df.describe()
# Out:
#           DONG_CODE           POP        AREA       DENSITY   TRANSPORT  \
# count  4.260000e+02    426.000000  426.000000    426.000000  426.000000
# mean   1.143415e+09  22854.523474    1.420728  23150.119718   15.812629
# std    1.920778e+07   9021.822196    1.571263  11326.683743    9.637535
# min    1.111052e+09    144.000000    0.230000    157.000000    2.070000
# 25%    1.126066e+09  16788.500000    0.670000  14512.000000    9.540000
# 50%    1.144064e+09  22141.500000    0.970000  23420.500000   13.497000
# 75%    1.161306e+09  27908.250000    1.487500  31708.500000   19.942500
# max    1.174070e+09  56012.000000   12.680000  55657.000000   73.811818
#
#          SECURITY      HEALTH  CONVENIENCE   EDUCATION   PARANTING  \
# count  426.000000  426.000000   426.000000  426.000000  426.000000
# mean    54.546948   40.485962    22.293099   43.064977   35.896714
# std     41.269881   33.313301    17.783109   39.861247   25.925220
# min      4.333333    1.000000     1.431667    0.700000    0.000000
# 25%     26.589286   22.480000    13.440833   20.842727   16.750000
# 50%     42.750000   33.070000    17.945000   31.662500   30.333333
# 75%     67.075000   46.221000    23.131500   52.250000   48.187500
# max    252.500000  242.700000   135.775000  342.280000  207.000000
#
#              MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM      MC_NUM  \
# count    426.000000    426.000000  426.000000     426.000000  426.000000
# mean    6970.138498      0.178404    0.518779       1.302817    0.204225
# std     3195.571959      0.590994    0.656479       2.164240    0.363035
# min       33.000000      0.000000    0.000000       0.000000    0.000000
# 25%     4710.250000      0.000000    0.000000       0.333333    0.000000
# 50%     6607.000000      0.000000    0.333333       0.666667    0.000000
# 75%     8666.500000      0.000000    0.729167       1.333333    0.285714
# max    20429.000000      4.000000    4.250000      18.500000    4.000000
#
#        NOISE_VIBRATION_NUM  LEISURE_NUM     GYM_NUM    GOLF_NUM  CAR_SHR_NUM  \
# count           426.000000   426.000000  426.000000  426.000000   426.000000
# mean           2452.551643     1.194836    7.448357    3.626761     4.133803
# std            4534.820198     1.606980    7.034213    4.318573     3.156750
# min             125.750000     0.000000    0.000000    0.000000     0.000000
# 25%             442.037500     0.000000    3.500000    1.333333     2.285714
# 50%            1014.000000     0.833333    6.000000    2.500000     3.500000
# 75%            2163.500000     1.750000    9.000000    4.500000     5.000000
# max           56112.000000    15.000000   60.000000   32.500000    24.000000
#
#        ANI_HSPT_NUM
# count    426.000000
# mean       2.093897
# std        1.393441
# min        0.000000
# 25%        1.350000
# 50%        2.000000
# 75%        2.500000
# max       12.000000

# %% [markdown]
# ### 1.3 면적 당 수치 계산

# %%
area = tmp_df['AREA']

# %%
columns = tmp_df.columns[6:]

# %%
for i in range(len(area)):
    for column in columns:
        tmp_df[column][i] = tmp_df[column][i] / area[i]
tmp_df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   5.328145  23.216602
# 1    종로구    사직동  1111053000   9636  1.23     7834  13.750678  36.314363
# 2    종로구    삼청동  1111054000   2739  1.49     1838   7.818792  15.436242
# 3    종로구    부암동  1111055000   9782  2.27     4309   3.819383  18.942731
# 4    종로구    평창동  1111056000  18329  8.87     2066   3.926719   2.480271
# ..   ...    ...         ...    ...   ...      ...        ...        ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979  16.303483  79.601990
# 422  강동구   성내3동  1174066000  23346  0.71    32882  12.765258  75.117371
# 423  강동구     길동  1174068500  45973  2.17    21186  12.709677  55.299539
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.945652  36.413043
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARANTING        MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   5.692607   2.853437   1249.027237      0.000000
# 1    57.907859    28.054201  12.276423  16.531165   2234.959350      0.813008
# 2     4.496644     9.315436   1.006711   7.382550    459.060403      0.000000
# 3     1.682819     4.854626   9.030837   2.202643   1138.766520      0.000000
# 4     1.517475     1.312289   2.213078   1.127396    518.263811      0.000000
# ..         ...          ...        ...        ...           ...           ...
# 421  84.378109    44.522388  67.995025  30.845771  12134.328358      0.000000
# 422  79.624413    42.014085  64.164319  29.107981  10028.169014      0.000000
# 423  52.949309    23.663594  34.778802  13.824885   6675.576037      0.000000
# 424  15.467391    12.885870  31.016304   0.000000     35.869565      0.000000
# 425  14.520408    12.096939  29.117347   0.000000   7143.877551      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000          7321.400778     0.389105
# 1    0.000000       5.962060  0.000000         18575.609756     0.813008
# 2    0.000000       0.671141  0.000000          9471.140940     0.000000
# 3    0.000000       0.000000  0.000000          2664.317181     0.000000
# 4    0.000000       0.112740  0.000000           454.565953     0.000000
# ..        ...            ...       ...                  ...          ...
# 421  0.995025       1.990050  0.000000          2152.736318     2.487562
# 422  0.938967       1.877934  0.000000          2031.455399     2.347418
# 423  0.460829       0.921659  0.000000          1994.009217     1.382488
# 424  0.000000       0.000000  0.543478          2351.630435     0.000000
# 425  0.000000       0.000000  0.510204          2207.653061     0.000000
#
#        GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0     0.000000  0.000000     0.389105      0.778210
# 1    14.634146  2.439024     4.065041      0.813008
# 2     2.013423  0.000000     0.671141      0.000000
# 3     0.881057  0.881057     2.202643      1.321586
# 4     0.563698  0.563698     0.000000      0.000000
# ..         ...       ...          ...           ...
# 421  14.925373  6.965174     9.950249      3.980100
# 422  14.084507  6.572770     9.389671      3.755869
# 423   8.294931  4.147465     4.608295      3.686636
# 424   4.347826  3.260870     2.173913      1.630435
# 425   4.081633  3.061224     2.040816      1.530612
#
# [426 rows x 23 columns]

# %%
tmp_df.describe()
# Out:
#           DONG_CODE           POP        AREA       DENSITY   TRANSPORT  \
# count  4.260000e+02    426.000000  426.000000    426.000000  426.000000
# mean   1.143415e+09  22854.523474    1.420728  23150.119718   14.899219
# std    1.920778e+07   9021.822196    1.571263  11326.683743    9.722790
# min    1.111052e+09    144.000000    0.230000    157.000000    1.402529
# 25%    1.126066e+09  16788.500000    0.670000  14512.000000    9.331860
# 50%    1.144064e+09  22141.500000    0.970000  23420.500000   13.183811
# 75%    1.161306e+09  27908.250000    1.487500  31708.500000   18.691749
# max    1.174070e+09  56012.000000   12.680000  55657.000000  136.688552
#
#          SECURITY      HEALTH  CONVENIENCE   EDUCATION   PARANTING  \
# count  426.000000  426.000000   426.000000  426.000000  426.000000
# mean    56.413573   40.203343    21.706931   42.454016   36.996223
# std     50.615331   28.324127    14.839065   42.415614   28.662723
# min      1.104101    0.357143     1.037855    1.006711    0.000000
# 25%     23.515357   19.444727    11.931636   19.589909   15.043297
# 50%     43.993671   35.314432    19.422745   32.325255   31.173590
# 75%     73.260354   52.296139    27.678636   52.244898   50.301671
# max    522.500000  211.043478   118.065217  390.982877  167.705167
#
#              MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM      MC_NUM  \
# count    426.000000    426.000000  426.000000     426.000000  426.000000
# mean    7109.301320      0.166431    0.498434       1.159477    0.188286
# std     3922.924848      0.582447    0.632681       1.733016    0.305553
# min       35.869565      0.000000    0.000000       0.000000    0.000000
# 25%     4088.947368      0.000000    0.000000       0.238595    0.000000
# 50%     7053.872138      0.000000    0.327602       0.648668    0.000000
# 75%     9397.635294      0.000000    0.745713       1.417603    0.316456
# max    27574.074074      5.405405    4.000000      18.686869    3.030303
#
#        NOISE_VIBRATION_NUM  LEISURE_NUM     GYM_NUM    GOLF_NUM  CAR_SHR_NUM  \
# count           426.000000   426.000000  426.000000  426.000000   426.000000
# mean           2254.690189     1.223275    7.136976    3.344890     4.052260
# std            3915.731918     1.647054    5.813202    3.367516     2.819812
# min              22.375445     0.000000    0.000000    0.000000     0.000000
# 25%             425.640244     0.000000    3.012962    1.204481     1.949320
# 50%             943.124462     0.730461    5.902233    2.443618     3.571429
# 75%            2071.379767     1.675408    9.523810    4.289551     5.570074
# max           34560.000000    12.121212   39.130435   28.260870    16.956522
#
#        ANI_HSPT_NUM
# count    426.000000
# mean       2.152990
# std        1.543945
# min        0.000000
# 25%        1.010498
# 50%        1.900506
# 75%        2.935049
# max        9.090909

# %% [markdown]
# ### 1.4 왜도/첨도 측정 : 일부 특성들을 범주화

# %% [markdown]
# #### 1.4.1 왜도/첨도 측정

# %%
columns = tmp_df.columns[6:]
skews = []
kurtosises = []
for column in columns:
    # 왜도 : 절댓값 3을 넘지 않아야 함
    skews.append(skew(tmp_df[column]))

    # 첨도 : 절댓값 8~10을 넘지 않아야 함
    kurtosises.append(kurtosis(tmp_df[column], fisher=True))
res = [skews,kurtosises]
standard_df = pd.DataFrame(data=res, index=['왜도','첨도'],columns=columns)

# %%
standard_df
# Out:
#     TRANSPORT   SECURITY    HEALTH  CONVENIENCE  EDUCATION  PARANTING  \
# 왜도   5.072204   3.132583  1.547339     2.001621    4.00260   1.361778
# 첨도  56.811500  19.030154  4.134766     7.570355   23.55307   2.534743
#
#       MZ_NUM  COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM     MC_NUM  \
# 왜도  0.685738      4.792325  1.895467       4.566057   3.144228
# 첨도  1.285944     28.221618  4.395937      32.014755  18.791080
#
#     NOISE_VIBRATION_NUM  LEISURE_NUM   GYM_NUM   GOLF_NUM  CAR_SHR_NUM  \
# 왜도             3.912226     2.655983  1.742896   2.604953     1.049841
# 첨도            19.032090     9.877211  4.295465  10.645659     1.592107
#
#     ANI_HSPT_NUM
# 왜도      1.033603
# 첨도      1.487151

# %%
over = []
for column in standard_df.columns:
    if((standard_df[column][0] > 3) and (standard_df[column][1] > 10)):
        over.append([column, standard_df[column][0], standard_df[column][1]])
over_std = pd.DataFrame(over).T

# %%
over_std.columns = over_std.iloc[0]
over_std = over_std.iloc[1:]
over_std
# Out:
# 0 TRANSPORT   SECURITY EDUCATION COLIVING_NUM STARBUCKS_NUM    MC_NUM  \
# 1  5.072204   3.132583    4.0026     4.792325      4.566057  3.144228
# 2   56.8115  19.030154  23.55307    28.221618     32.014755  18.79108
#
# 0 NOISE_VIBRATION_NUM
# 1            3.912226
# 2            19.03209

# %%
over_std.columns
# Out:
# Index(['TRANSPORT', 'SECURITY', 'EDUCATION', 'COLIVING_NUM', 'STARBUCKS_NUM',
#        'MC_NUM', 'NOISE_VIBRATION_NUM'],
#       dtype='object', name=0)

# %% [markdown]
# #### 1.4.2 범주화 작업
# - 소음

# %%
tmp_df.hist(figsize = (20, 20), bins = 22, legend = False)
# Out:
# array([[<AxesSubplot:title={'center':'DONG_CODE'}>,
#         <AxesSubplot:title={'center':'POP'}>,
#         <AxesSubplot:title={'center':'AREA'}>,
#         <AxesSubplot:title={'center':'DENSITY'}>,
#         <AxesSubplot:title={'center':'TRANSPORT'}>],
#        [<AxesSubplot:title={'center':'SECURITY'}>,
#         <AxesSubplot:title={'center':'HEALTH'}>,
#         <AxesSubplot:title={'center':'CONVENIENCE'}>,
#         <AxesSubplot:title={'center':'EDUCATION'}>,
#         <AxesSubplot:title={'center':'PARANTING'}>],
#        [<AxesSubplot:title={'center':'MZ_NUM'}>,
#         <AxesSubplot:title={'center':'COLIVING_NUM'}>,
#         <AxesSubplot:title={'center':'KIDS_NUM'}>,
#         <AxesSubplot:title={'center':'STARBUCKS_NUM'}>,
#         <AxesSubplot:title={'center':'MC_NUM'}>],
#        [<AxesSubplot:title={'center':'NOISE_VIBRATION_NUM'}>,
#         <AxesSubplot:title={'center':'LEISURE_NUM'}>,
#         <AxesSubplot:title={'center':'GYM_NUM'}>,
#         <AxesSubplot:title={'center':'GOLF_NUM'}>,
#         <AxesSubplot:title={'center':'CAR_SHR_NUM'}>],
#        [<AxesSubplot:title={'center':'ANI_HSPT_NUM'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
origin_df = tmp_df.copy()

# %% [markdown]
# **소음**

# %%
noise = tmp_df['NOISE_VIBRATION_NUM']
noise
# Out:
# 0       7321.400778
# 1      18575.609756
# 2       9471.140940
# 3       2664.317181
# 4        454.565953
#            ...
# 421     2152.736318
# 422     2031.455399
# 423     1994.009217
# 424     2351.630435
# 425     2207.653061
# Name: NOISE_VIBRATION_NUM, Length: 426, dtype: float64

# %%
for i in range(len(noise)):
    if (noise[i] < 500):
        noise[i] = 4
    elif (noise[i] >= 500 and noise[i] < 1000):
        noise[i] = 3
    elif (noise[i] >= 1000 and noise[i] < 1500):
        noise[i] = 2
    else:
        noise[i] = 1
noise
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      4.0
#       ...
# 421    1.0
# 422    1.0
# 423    1.0
# 424    1.0
# 425    1.0
# Name: NOISE_VIBRATION_NUM, Length: 426, dtype: float64

# %%
noise.value_counts()
# Out:
# 1.0    147
# 4.0    124
# 3.0     99
# 2.0     56
# Name: NOISE_VIBRATION_NUM, dtype: int64

# %%
tmp_df['NOISE_VIBRATION_NUM'] = noise
tmp_df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   5.328145  23.216602
# 1    종로구    사직동  1111053000   9636  1.23     7834  13.750678  36.314363
# 2    종로구    삼청동  1111054000   2739  1.49     1838   7.818792  15.436242
# 3    종로구    부암동  1111055000   9782  2.27     4309   3.819383  18.942731
# 4    종로구    평창동  1111056000  18329  8.87     2066   3.926719   2.480271
# ..   ...    ...         ...    ...   ...      ...        ...        ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979  16.303483  79.601990
# 422  강동구   성내3동  1174066000  23346  0.71    32882  12.765258  75.117371
# 423  강동구     길동  1174068500  45973  2.17    21186  12.709677  55.299539
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.945652  36.413043
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARANTING        MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   5.692607   2.853437   1249.027237      0.000000
# 1    57.907859    28.054201  12.276423  16.531165   2234.959350      0.813008
# 2     4.496644     9.315436   1.006711   7.382550    459.060403      0.000000
# 3     1.682819     4.854626   9.030837   2.202643   1138.766520      0.000000
# 4     1.517475     1.312289   2.213078   1.127396    518.263811      0.000000
# ..         ...          ...        ...        ...           ...           ...
# 421  84.378109    44.522388  67.995025  30.845771  12134.328358      0.000000
# 422  79.624413    42.014085  64.164319  29.107981  10028.169014      0.000000
# 423  52.949309    23.663594  34.778802  13.824885   6675.576037      0.000000
# 424  15.467391    12.885870  31.016304   0.000000     35.869565      0.000000
# 425  14.520408    12.096939  29.117347   0.000000   7143.877551      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000                  1.0     0.389105
# 1    0.000000       5.962060  0.000000                  1.0     0.813008
# 2    0.000000       0.671141  0.000000                  1.0     0.000000
# 3    0.000000       0.000000  0.000000                  1.0     0.000000
# 4    0.000000       0.112740  0.000000                  4.0     0.000000
# ..        ...            ...       ...                  ...          ...
# 421  0.995025       1.990050  0.000000                  1.0     2.487562
# 422  0.938967       1.877934  0.000000                  1.0     2.347418
# 423  0.460829       0.921659  0.000000                  1.0     1.382488
# 424  0.000000       0.000000  0.543478                  1.0     0.000000
# 425  0.000000       0.000000  0.510204                  1.0     0.000000
#
#        GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0     0.000000  0.000000     0.389105      0.778210
# 1    14.634146  2.439024     4.065041      0.813008
# 2     2.013423  0.000000     0.671141      0.000000
# 3     0.881057  0.881057     2.202643      1.321586
# 4     0.563698  0.563698     0.000000      0.000000
# ..         ...       ...          ...           ...
# 421  14.925373  6.965174     9.950249      3.980100
# 422  14.084507  6.572770     9.389671      3.755869
# 423   8.294931  4.147465     4.608295      3.686636
# 424   4.347826  3.260870     2.173913      1.630435
# 425   4.081633  3.061224     2.040816      1.530612
#
# [426 rows x 23 columns]

# %% [markdown]
# #### 1.4.3 최댓값 제한

# %% [markdown]
# **교육**

# %%
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['EDUCATION'].describe()
# Out:
# count    426.000000
# mean      42.454016
# std       42.415614
# min        1.006711
# 25%       19.589909
# 50%       32.325255
# 75%       52.244898
# max      390.982877
# Name: EDUCATION, dtype: float64

# %%
e = tmp_df['EDUCATION'].quantile(0.95)
e
# Out:
# 105.6954219807904

# %%
tmp_df[tmp_df['EDUCATION'] > e] = e

# %%
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['EDUCATION'] = np.log1p(tmp_df['EDUCATION'])
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 1.4.4 RobustScaling

# %%
df = tmp_df.copy()
df
# Out:
#       GU   DONG     DONG_CODE      POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1.111052e+09  12177.0  2.57   4738.0   5.328145  23.216602
# 1    종로구    사직동  1.111053e+09   9636.0  1.23   7834.0  13.750678  36.314363
# 2    종로구    삼청동  1.111054e+09   2739.0  1.49   1838.0   7.818792  15.436242
# 3    종로구    부암동  1.111055e+09   9782.0  2.27   4309.0   3.819383  18.942731
# 4    종로구    평창동  1.111056e+09  18329.0  8.87   2066.0   3.926719   2.480271
# ..   ...    ...           ...      ...   ...      ...        ...        ...
# 421  강동구   성내2동  1.174065e+09  24106.0  0.67  35979.0  16.303483  79.601990
# 422  강동구   성내3동  1.174066e+09  23346.0  0.71  32882.0  12.765258  75.117371
# 423  강동구     길동  1.174068e+09  45973.0  2.17  21186.0  12.709677  55.299539
# 424  강동구   둔촌1동  1.174069e+09    144.0  0.92    157.0   4.945652  36.413043
# 425  강동구   둔촌2동  1.174070e+09  24785.0  0.98  25291.0  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARANTING        MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   1.901003   2.853437   1249.027237      0.000000
# 1    57.907859    28.054201   2.585990  16.531165   2234.959350      0.813008
# 2     4.496644     9.315436   0.696497   7.382550    459.060403      0.000000
# 3     1.682819     4.854626   2.305664   2.202643   1138.766520      0.000000
# 4     1.517475     1.312289   1.167229   1.127396    518.263811      0.000000
# ..         ...          ...        ...        ...           ...           ...
# 421  84.378109    44.522388   4.234034  30.845771  12134.328358      0.000000
# 422  79.624413    42.014085   4.176912  29.107981  10028.169014      0.000000
# 423  52.949309    23.663594   3.577356  13.824885   6675.576037      0.000000
# 424  15.467391    12.885870   3.466245   0.000000     35.869565      0.000000
# 425  14.520408    12.096939   3.405101   0.000000   7143.877551      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000                  1.0     0.389105
# 1    0.000000       5.962060  0.000000                  1.0     0.813008
# 2    0.000000       0.671141  0.000000                  1.0     0.000000
# 3    0.000000       0.000000  0.000000                  1.0     0.000000
# 4    0.000000       0.112740  0.000000                  4.0     0.000000
# ..        ...            ...       ...                  ...          ...
# 421  0.995025       1.990050  0.000000                  1.0     2.487562
# 422  0.938967       1.877934  0.000000                  1.0     2.347418
# 423  0.460829       0.921659  0.000000                  1.0     1.382488
# 424  0.000000       0.000000  0.543478                  1.0     0.000000
# 425  0.000000       0.000000  0.510204                  1.0     0.000000
#
#        GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0     0.000000  0.000000     0.389105      0.778210
# 1    14.634146  2.439024     4.065041      0.813008
# 2     2.013423  0.000000     0.671141      0.000000
# 3     0.881057  0.881057     2.202643      1.321586
# 4     0.563698  0.563698     0.000000      0.000000
# ..         ...       ...          ...           ...
# 421  14.925373  6.965174     9.950249      3.980100
# 422  14.084507  6.572770     9.389671      3.755869
# 423   8.294931  4.147465     4.608295      3.686636
# 424   4.347826  3.260870     2.173913      1.630435
# 425   4.081633  3.061224     2.040816      1.530612
#
# [426 rows x 23 columns]

# %%
col = df.columns[6:]
data = df[col]

# %%
scaler = RobustScaler()
scaler.fit(data)
df_scaled = scaler.transform(data)
df_scaled
# Out:
# array([[-0.78277238, -0.40156946, -0.92093458, ..., -0.77933285,
#         -0.84576644, -0.54693279],
#        [ 0.00951441, -0.16266521,  0.66447526, ..., -0.00146491,
#          0.12967946, -0.53039846],
#        [-0.5484834 , -0.54348387, -0.91713562, ..., -0.77933285,
#         -0.77092543, -0.9167005 ],
#        ...,
#        [-0.0884099 ,  0.18362596,  0.51764285, ...,  0.54340111,
#          0.27383736,  0.83501015],
#        [-0.81875256, -0.16086528, -0.59227027, ...,  0.26064276,
#         -0.37214997, -0.14199695],
#        [ 0.58105489, -0.20152917, -0.6203123 , ...,  0.19697079,
#         -0.4074685 , -0.18942778]])

# %%
df[col] = df_scaled
data = df[col]

# %%
df
# Out:
#       GU   DONG     DONG_CODE      POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# 0    종로구  청운효자동  1.111052e+09  12177.0  2.57   4738.0  -0.782772 -0.401569
# 1    종로구    사직동  1.111053e+09   9636.0  1.23   7834.0   0.009514 -0.162665
# 2    종로구    삼청동  1.111054e+09   2739.0  1.49   1838.0  -0.548483 -0.543484
# 3    종로구    부암동  1.111055e+09   9782.0  2.27   4309.0  -0.924698 -0.479525
# 4    종로구    평창동  1.111056e+09  18329.0  8.87   2066.0  -0.914601 -0.779802
# ..   ...    ...           ...      ...   ...      ...        ...       ...
# 421  강동구   성내2동  1.174065e+09  24106.0  0.67  35979.0   0.249650  0.626905
# 422  강동구   성내3동  1.174066e+09  23346.0  0.71  32882.0  -0.083182  0.545105
# 423  강동구     길동  1.174068e+09  45973.0  2.17  21186.0  -0.088410  0.183626
# 424  강동구   둔촌1동  1.174069e+09    144.0  0.92    157.0  -0.818753 -0.160865
# 425  강동구   둔촌2동  1.174070e+09  24785.0  0.98  25291.0   0.581055 -0.201529
#
#        HEALTH  CONVENIENCE  EDUCATION  PARANTING    MZ_NUM  COLIVING_NUM  \
# 0   -0.920935    -0.924791  -1.689682  -0.748320 -0.933494      0.000000
# 1    0.664475     0.506833  -0.968695  -0.396493 -0.762154      0.813008
# 2   -0.917136    -0.634214  -2.957494  -0.631820 -1.070778      0.000000
# 3   -1.000458    -0.905843  -1.263754  -0.765061 -0.952656      0.000000
# 4   -1.005355    -1.121544  -2.462022  -0.792719 -1.060490      0.000000
# ..        ...          ...        ...        ...       ...           ...
# 421  1.448311     1.509619   0.765966  -0.028283  0.958204      0.000000
# 422  1.307545     1.356882   0.705841  -0.072983  0.592186      0.000000
# 423  0.517643     0.239478   0.074774  -0.466106  0.009557      0.000000
# 424 -0.592270    -0.416802  -0.042176  -0.821719 -1.144322      0.000000
# 425 -0.620312    -0.464842  -0.106534  -0.821719  0.090940      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0   -0.418214      -0.407129  0.000000            -0.666667    -0.211374
# 1   -0.418214       4.116073  0.000000            -0.666667     0.017533
# 2   -0.418214       0.012777  0.000000            -0.666667    -0.421491
# 3   -0.418214      -0.507717  0.000000            -0.666667    -0.421491
# 4   -0.418214      -0.420283  0.000000             0.333333    -0.421491
# ..        ...            ...       ...                  ...          ...
# 421  0.815617       1.035638  0.000000            -0.666667     0.921792
# 422  0.746106       0.948688  0.000000            -0.666667     0.846114
# 423  0.153215       0.207062  0.000000            -0.666667     0.325053
# 424 -0.418214      -0.507717  1.433389            -0.666667    -0.421491
# 425 -0.418214      -0.507717  1.345631            -0.666667    -0.421491
#
#       GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0   -0.876047 -0.779333    -0.845766     -0.546933
# 1    1.294673 -0.001465     0.129679     -0.530398
# 2   -0.577391 -0.779333    -0.770925     -0.916701
# 3   -0.745357 -0.498341    -0.364526     -0.288747
# 4   -0.792432 -0.599555    -0.949019     -0.916701
# ..        ...       ...          ...           ...
# 421  1.337871  1.442041     1.691378      0.974450
# 422  1.213143  1.316893     1.542623      0.867906
# 423  0.354361  0.543401     0.273837      0.835010
# 424 -0.231123  0.260643    -0.372150     -0.141997
# 425 -0.270608  0.196971    -0.407469     -0.189428
#
# [426 rows x 23 columns]

# %% [markdown]
# ## 2. K-means 군집화

# %% [markdown]
# ### 2.1 1차 k-means clustering

# %% [markdown]
# #### 2.1.1 Elbow 관측

# %%
# 차원 축소 및 변환
pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(data)

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# #### 2.1.2 k-means, n_cluster = 3

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
kmeans.fit(pca_transformed)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
kmeans.labels_
df = tmp_df.copy()
df['km_cluster'] = kmeans.labels_
df.groupby('km_cluster').count()
# Out:
#              GU  DONG  DONG_CODE  POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# km_cluster
# 0           118   118        118  118   118      118        118       118
# 1            22    22         22   22    22       22         22        22
# 2           286   286        286  286   286      286        286       286
#
#             HEALTH  CONVENIENCE  EDUCATION  PARANTING  MZ_NUM  COLIVING_NUM  \
# km_cluster
# 0              118          118        118        118     118           118
# 1               22           22         22         22      22            22
# 2              286          286        286        286     286           286
#
#             KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# km_cluster
# 0                118            118     118                  118          118
# 1                 22             22      22                   22           22
# 2                286            286     286                  286          286
#
#             GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# km_cluster
# 0               118       118          118           118
# 1                22        22           22            22
# 2               286       286          286           286

# %%
# 범주화 하지 않은 모델, minMaxScale 적용

df['pca_x'] = pca_transformed[:,0]
df['pca_y'] = pca_transformed[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df[df['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>','<']
for i in range(marker_n):
    plt.scatter(x = df.loc[markers[i], 'pca_x'], y = df.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('2 Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2'])
plt.show()

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed)      
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 426 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
score = silhouette_score(data,df['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
# Out:
# Silhouette Score :  0.341

# %% [markdown]
# #### 2.1.3 각 군집 별 데이터 확인

# %% [markdown]
# **km_cluster == 0**

# %%
df_cluster_0 = df[df['km_cluster'] == 0][col]

# %%
df_cluster_0.describe()
# Out:
#         TRANSPORT    SECURITY      HEALTH  CONVENIENCE   EDUCATION  \
# count  176.000000  176.000000  176.000000   176.000000  176.000000
# mean    17.707043   68.993367   50.794611    25.694497   52.925540
# std     11.781111   55.730812   17.844746     8.063506   25.405286
# min      5.204620    6.812652   16.947368     8.518519    9.750000
# 25%     11.394158   35.360597   38.823715    20.364375   36.585122
# 50%     15.669935   54.240029   47.933636    25.008791   47.664972
# 75%     21.071422   81.372549   57.488432    29.858237   64.576589
# max    136.688552  522.500000  121.068783    55.423077  151.726190
#
#         PARANTING        MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM  \
# count  176.000000    176.000000    176.000000  176.000000     176.000000
# mean    50.197441   9078.390517      0.175208    0.675270       1.159939
# std     28.621003   3542.377218      0.542520    0.627109       0.954849
# min      4.411765    402.970297      0.000000    0.000000       0.000000
# 25%     30.690559   6838.011656      0.000000    0.093750       0.554408
# 50%     47.141001   8960.049020      0.000000    0.537883       0.980392
# 75%     64.933052  10972.322958      0.000000    1.044408       1.566612
# max    167.705167  27574.074074      4.347826    2.816901       5.962060
#
#            MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM     GYM_NUM    GOLF_NUM  \
# count  176.000000           176.000000   176.000000  176.000000  176.000000
# mean     0.209674             2.420455     1.661577    9.154134    4.064780
# std      0.249985             1.230299     1.678902    3.706543    2.280027
# min      0.000000             1.000000     0.000000    0.000000    0.000000
# 25%      0.000000             1.000000     0.530777    6.680506    2.435329
# 50%      0.126276             3.000000     1.246118    8.740079    3.888220
# 75%      0.402459             4.000000     2.424272   11.125887    5.388889
# max      0.980392             4.000000    10.344828   25.751073   12.017167
#
#        CAR_SHR_NUM  ANI_HSPT_NUM
# count   176.000000    176.000000
# mean      5.082212      2.900728
# std       2.105153      1.225942
# min       0.000000      0.000000
# 25%       3.598020      2.061856
# 50%       4.992877      2.735588
# 75%       6.319121      3.736007
# max      10.714286      6.349206

# %% [markdown]
# **km_cluster == 1**

# %%
df_cluster_1 = df[df['km_cluster'] == 1][col]

# %%
df_cluster_1.describe()
# Out:
#         TRANSPORT    SECURITY      HEALTH  CONVENIENCE   EDUCATION  \
# count  211.000000  211.000000  211.000000   211.000000  211.000000
# mean    11.709916   37.243970   21.765115    12.727573   22.118083
# std      6.456744   29.768643   14.923547     7.391748   12.751528
# min      1.402529    1.104101    0.357143     1.037855    1.006711
# 25%      6.706333   15.812500   12.514483     7.067887   11.362764
# 50%     10.889773   31.842105   19.477833    11.961905   21.711174
# 75%     15.209524   49.062604   28.333463    16.864480   29.526528
# max     37.400000  181.538462  134.900000    57.468750   57.340909
#
#         PARANTING        MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM  \
# count  211.000000    211.000000    211.000000  211.000000     211.000000
# mean    22.337498   5092.583423      0.081971    0.225358       0.524839
# std     17.128335   2931.723121      0.391200    0.306777       0.741695
# min      0.000000     35.869565      0.000000    0.000000       0.000000
# 25%      7.925640   2854.374021      0.000000    0.000000       0.089233
# 50%     18.670886   4646.979866      0.000000    0.069444       0.326797
# 75%     31.314100   7140.410113      0.000000    0.370829       0.661793
# max     88.333333  16142.372881      3.508772    1.379310       5.128205
#
#            MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM     GYM_NUM    GOLF_NUM  \
# count  211.000000           211.000000   211.000000  211.000000  211.000000
# mean     0.128900             2.630332     0.573557    3.389065    1.600110
# std      0.254435             1.225067     0.774408    2.076805    1.213156
# min      0.000000             1.000000     0.000000    0.000000    0.000000
# 25%      0.000000             1.000000     0.000000    1.891232    0.653595
# 50%      0.000000             3.000000     0.284091    3.125000    1.449275
# 75%      0.161873             4.000000     0.893142    4.571578    2.317354
# max      1.449275             4.000000     4.631579   10.000000    5.882353
#
#        CAR_SHR_NUM  ANI_HSPT_NUM
# count   211.000000    211.000000
# mean      2.324816      1.190056
# std       1.618662      0.801256
# min       0.000000      0.000000
# 25%       1.143310      0.608583
# 50%       2.158273      1.146789
# 75%       3.304149      1.619815
# max       8.974359      4.545455

# %% [markdown]
# **km_cluster == 2**

# %%
df_cluster_2 = df[df['km_cluster'] == 2][col]

# %%
df_cluster_2.describe()
# Out:
#        TRANSPORT    SECURITY      HEALTH  CONVENIENCE   EDUCATION   PARANTING  \
# count  39.000000   39.000000   39.000000    39.000000   39.000000   39.000000
# mean   19.482964  103.355692   92.162384    52.292389  105.220518   56.728958
# std     8.552188   66.461631   33.125421    19.491597   96.968636   37.345933
# min     3.775510    9.523810   31.087302    22.914286    1.166667    6.122449
# 25%    13.827045   49.661097   71.709909    39.850487   43.733277   29.980926
# 50%    17.524590   94.642857   89.411392    49.935484   75.953125   45.614035
# 75%    26.340510  127.265391  102.104965    59.266640  115.820591   89.273575
# max    38.257143  321.304348  211.043478   118.065217  390.982877  154.782609
#
#              MZ_NUM  COLIVING_NUM   KIDS_NUM  STARBUCKS_NUM     MC_NUM  \
# count     39.000000     39.000000  39.000000      39.000000  39.000000
# mean    9134.116128      0.583770   1.177818       4.590942   0.413054
# std     4699.025128      1.172289   1.055030       3.468422   0.570162
# min     1106.666667      0.000000   0.000000       1.282051   0.000000
# 25%     6167.925719      0.000000   0.329461       2.525804   0.000000
# 50%     8179.200000      0.000000   1.041667       3.508772   0.320513
# 75%    12060.818713      0.800051   1.820589       5.128949   0.605450
# max    19633.333333      5.405405   4.000000      18.686869   3.030303
#
#        NOISE_VIBRATION_NUM  LEISURE_NUM    GYM_NUM   GOLF_NUM  CAR_SHR_NUM  \
# count            39.000000    39.000000  39.000000  39.000000    39.000000
# mean              1.820513     2.760441  18.311065   9.535870     8.750184
# std               1.097168     2.895951   8.115304   6.009667     3.147577
# min               1.000000     0.000000   1.351351   0.000000     0.000000
# 25%               1.000000     0.905051  14.628503   4.798851     7.202020
# 50%               1.000000     1.760563  18.181818   9.090909     8.333333
# 75%               3.000000     3.044522  23.548644  12.651920    10.045279
# max               4.000000    12.121212  39.130435  28.260870    16.956522
#
#        ANI_HSPT_NUM
# count     39.000000
# mean       3.988305
# std        2.235161
# min        0.000000
# 25%        2.671946
# 50%        4.000000
# 75%        5.064103
# max        9.090909

# %% [markdown]
# ### 2.2 2차 k-means_clustering

# %% [markdown]
# #### 2.2.1 km_cluster == 0

# %% [markdown]
# - Elbow 관측

# %%
df_0 = df[df['km_cluster'] == 0][tmp_df.columns]
df_0
# Out:
#       GU         DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT  \
# 1    종로구          사직동  1111053000   9636  1.23     7834  13.750678
# 8    종로구  종로1.2.3.4가동  1111061500   8595  2.35     3657  21.558865
# 15   종로구         숭인1동  1111070000   6106  0.23    26548  33.173913
# 16   종로구         숭인2동  1111071000  10175  0.35    29071  19.142857
# 24    중구          신당동  1114061500   9095  0.55    16536  32.636364
# ..   ...          ...         ...    ...   ...      ...        ...
# 417  강동구         천호1동  1174060000  26973  0.71    37990  13.619718
# 419  강동구         천호3동  1174062000  27000  0.79    34177   6.354430
# 421  강동구         성내2동  1174065000  24106  0.67    35979  16.303483
# 422  강동구         성내3동  1174066000  23346  0.71    32882  12.765258
# 423  강동구           길동  1174068500  45973  2.17    21186  12.709677
#
#        SECURITY     HEALTH  CONVENIENCE  EDUCATION  PARANTING        MZ_NUM  \
# 1     36.314363  57.907859    28.054201  12.276423  16.531165   2234.959350
# 8     36.453901  63.449645    38.234752  31.765957  29.929078   1008.510638
# 15    80.434783  58.130435    32.152174  24.347826  67.391304   7308.695652
# 16    52.857143  38.200000    21.128571  16.000000  44.285714  11994.285714
# 24   142.424242  62.496970    42.000000  23.418182  56.666667   6552.727273
# ..          ...        ...          ...        ...        ...           ...
# 417  125.821596  88.375587    44.502347  43.431925  38.497653  10816.901408
# 419  113.080169  79.426160    39.995781  39.033755  34.599156  12037.974684
# 421   79.601990  84.378109    44.522388  67.995025  30.845771  12134.328358
# 422   75.117371  79.624413    42.014085  64.164319  29.107981  10028.169014
# 423   55.299539  52.949309    23.663594  34.778802  13.824885   6675.576037
#
#      COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  \
# 1        0.813008  0.000000       5.962060  0.000000                  1.0
# 8        1.276596  0.425532       5.673759  0.425532                  1.0
# 15       4.347826  0.000000       2.173913  0.000000                  1.0
# 16       0.000000  0.000000       1.428571  0.000000                  1.0
# 24       1.818182  0.303030       3.939394  0.000000                  1.0
# ..            ...       ...            ...       ...                  ...
# 417      0.000000  2.816901       1.877934  0.469484                  1.0
# 419      0.000000  2.531646       1.687764  0.421941                  1.0
# 421      0.000000  0.995025       1.990050  0.000000                  1.0
# 422      0.000000  0.938967       1.877934  0.000000                  1.0
# 423      0.000000  0.460829       0.921659  0.000000                  1.0
#
#      LEISURE_NUM    GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 1       0.813008  14.634146  2.439024     4.065041      0.813008
# 8       1.702128   4.255319  2.127660     7.659574      0.000000
# 15      6.521739  10.869565  4.347826     8.695652      4.347826
# 16      4.285714   7.142857  2.857143     5.714286      2.857143
# 24      0.000000  11.515152  2.424242     9.393939      2.727273
# ..           ...        ...       ...          ...           ...
# 417     6.103286   6.572770  3.286385     7.981221      1.877934
# 419     5.485232   5.907173  2.953586     7.172996      1.687764
# 421     2.487562  14.925373  6.965174     9.950249      3.980100
# 422     2.347418  14.084507  6.572770     9.389671      3.755869
# 423     1.382488   8.294931  4.147465     4.608295      3.686636
#
# [176 rows x 23 columns]

# %%
col_0 = df_0.columns[6:]
data_0 = df_0[col_0].values

# %%
pca_transformed_0 = pca.fit_transform(data_0)
df_0['pca_x'] = pca_transformed_0[:,0]
df_0['pca_y'] = pca_transformed_0[:,1]
df_0
# Out:
#       GU         DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT  \
# 1    종로구          사직동  1111053000   9636  1.23     7834  13.750678
# 8    종로구  종로1.2.3.4가동  1111061500   8595  2.35     3657  21.558865
# 15   종로구         숭인1동  1111070000   6106  0.23    26548  33.173913
# 16   종로구         숭인2동  1111071000  10175  0.35    29071  19.142857
# 24    중구          신당동  1114061500   9095  0.55    16536  32.636364
# ..   ...          ...         ...    ...   ...      ...        ...
# 417  강동구         천호1동  1174060000  26973  0.71    37990  13.619718
# 419  강동구         천호3동  1174062000  27000  0.79    34177   6.354430
# 421  강동구         성내2동  1174065000  24106  0.67    35979  16.303483
# 422  강동구         성내3동  1174066000  23346  0.71    32882  12.765258
# 423  강동구           길동  1174068500  45973  2.17    21186  12.709677
#
#        SECURITY     HEALTH  CONVENIENCE  EDUCATION  PARANTING        MZ_NUM  \
# 1     36.314363  57.907859    28.054201  12.276423  16.531165   2234.959350
# 8     36.453901  63.449645    38.234752  31.765957  29.929078   1008.510638
# 15    80.434783  58.130435    32.152174  24.347826  67.391304   7308.695652
# 16    52.857143  38.200000    21.128571  16.000000  44.285714  11994.285714
# 24   142.424242  62.496970    42.000000  23.418182  56.666667   6552.727273
# ..          ...        ...          ...        ...        ...           ...
# 417  125.821596  88.375587    44.502347  43.431925  38.497653  10816.901408
# 419  113.080169  79.426160    39.995781  39.033755  34.599156  12037.974684
# 421   79.601990  84.378109    44.522388  67.995025  30.845771  12134.328358
# 422   75.117371  79.624413    42.014085  64.164319  29.107981  10028.169014
# 423   55.299539  52.949309    23.663594  34.778802  13.824885   6675.576037
#
#      COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  \
# 1        0.813008  0.000000       5.962060  0.000000                  1.0
# 8        1.276596  0.425532       5.673759  0.425532                  1.0
# 15       4.347826  0.000000       2.173913  0.000000                  1.0
# 16       0.000000  0.000000       1.428571  0.000000                  1.0
# 24       1.818182  0.303030       3.939394  0.000000                  1.0
# ..            ...       ...            ...       ...                  ...
# 417      0.000000  2.816901       1.877934  0.469484                  1.0
# 419      0.000000  2.531646       1.687764  0.421941                  1.0
# 421      0.000000  0.995025       1.990050  0.000000                  1.0
# 422      0.000000  0.938967       1.877934  0.000000                  1.0
# 423      0.000000  0.460829       0.921659  0.000000                  1.0
#
#      LEISURE_NUM    GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM        pca_x  \
# 1       0.813008  14.634146  2.439024     4.065041      0.813008 -6843.438110
# 8       1.702128   4.255319  2.127660     7.659574      0.000000 -8069.875689
# 15      6.521739  10.869565  4.347826     8.695652      4.347826 -1769.604096
# 16      4.285714   7.142857  2.857143     5.714286      2.857143  2915.891142
# 24      0.000000  11.515152  2.424242     9.393939      2.727273 -2525.481958
# ..           ...        ...       ...          ...           ...          ...
# 417     6.103286   6.572770  3.286385     7.981221      1.877934  1738.611401
# 419     5.485232   5.907173  2.953586     7.172996      1.687764  2959.648198
# 421     2.487562  14.925373  6.965174     9.950249      3.980100  3055.941502
# 422     2.347418  14.084507  6.572770     9.389671      3.755869   949.776215
# 423     1.382488   8.294931  4.147465     4.608295      3.686636 -2402.839038
#
#          pca_y
# 1   -17.654546
# 8   -16.616380
# 15   20.575869
# 16  -15.788167
# 24   82.243105
# ..         ...
# 417  54.913525
# 419  40.446337
# 421   2.587444
# 422   1.898436
# 423 -10.286488
#
# [176 rows x 25 columns]

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_0)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 3(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
# label
label_0 = kmeans.fit(pca_transformed_0)
# Getting unique labels
u_labels = np.unique(label_0)

# %%
df_0['km_cluster'] = kmeans.labels_
df_0.groupby('km_cluster').count()
# Out:
#             GU  DONG  DONG_CODE  POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# km_cluster
# 0           38    38         38   38    38       38         38        38
# 1           47    47         47   47    47       47         47        47
# 2           91    91         91   91    91       91         91        91
#
#             HEALTH  CONVENIENCE  EDUCATION  PARANTING  MZ_NUM  COLIVING_NUM  \
# km_cluster
# 0               38           38         38         38      38            38
# 1               47           47         47         47      47            47
# 2               91           91         91         91      91            91
#
#             KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# km_cluster
# 0                 38             38      38                   38           38
# 1                 47             47      47                   47           47
# 2                 91             91      91                   91           91
#
#             GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  pca_x  pca_y
# km_cluster
# 0                38        38           38            38     38     38
# 1                47        47           47            47     47     47
# 2                91        91           91            91     91     91

# %%
df_0['pca_x'] = pca_transformed_0[:,0]
df_0['pca_y'] = pca_transformed_0[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_0['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_0[df_0['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_0.loc[markers[i], 'pca_x'], y = df_0.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2'])
plt.show()

# %%
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
visualizer.fit(pca_transformed_0)      
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 176 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
score = silhouette_score(data_0,df_0['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
# Out:
# Silhouette Score :  0.514

# %% [markdown]
# #### 2.2.2 km_cluster == 1

# %% [markdown]
# - Elbow 관측

# %%
df_1 = df[df['km_cluster'] == 1][tmp_df.columns]
df_1
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   5.328145  23.216602
# 2    종로구    삼청동  1111054000   2739  1.49     1838   7.818792  15.436242
# 3    종로구    부암동  1111055000   9782  2.27     4309   3.819383  18.942731
# 4    종로구    평창동  1111056000  18329  8.87     2066   3.926719   2.480271
# 5    종로구    무악동  1111057000   8297  0.36    23047  13.416667  36.111111
# ..   ...    ...         ...    ...   ...      ...        ...        ...
# 415  강동구   암사2동  1174058000  15252  1.18    12925   9.138418  38.135593
# 416  강동구   암사3동  1174059000  17947  2.51     7150   5.407703  17.928287
# 418  강동구   천호2동  1174061000  33753  1.57    21499   9.121019  56.900212
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.945652  36.413043
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARANTING       MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   5.692607   2.853437  1249.027237           0.0
# 2     4.496644     9.315436   1.006711   7.382550   459.060403           0.0
# 3     1.682819     4.854626   9.030837   2.202643  1138.766520           0.0
# 4     1.517475     1.312289   2.213078   1.127396   518.263811           0.0
# 5    13.888889     9.388889  43.888889  36.111111  5061.111111           0.0
# ..         ...          ...        ...        ...          ...           ...
# 415  24.271186    13.604520  40.528249  11.581921  3988.135593           0.0
# 416  11.410359     6.395750  19.053121   5.444887  1699.203187           0.0
# 418  39.966030    20.125265  19.641189  17.409766  7136.942675           0.0
# 424  15.467391    12.885870  31.016304   0.000000    35.869565           0.0
# 425  14.520408    12.096939  29.117347   0.000000  7143.877551           0.0
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000                  1.0     0.389105
# 2    0.000000       0.671141  0.000000                  1.0     0.000000
# 3    0.000000       0.000000  0.000000                  1.0     0.000000
# 4    0.000000       0.112740  0.000000                  4.0     0.000000
# 5    0.000000       0.000000  0.000000                  1.0     0.000000
# ..        ...            ...       ...                  ...          ...
# 415  1.129944       0.282486  0.000000                  2.0     0.282486
# 416  0.531208       0.132802  0.000000                  3.0     0.132802
# 418  1.273885       0.849257  0.212314                  3.0     2.760085
# 424  0.000000       0.000000  0.543478                  1.0     0.000000
# 425  0.000000       0.000000  0.510204                  1.0     0.000000
#
#       GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 0    0.000000  0.000000     0.389105      0.778210
# 2    2.013423  0.000000     0.671141      0.000000
# 3    0.881057  0.881057     2.202643      1.321586
# 4    0.563698  0.563698     0.000000      0.000000
# 5    0.000000  2.777778     2.777778      0.000000
# ..        ...       ...          ...           ...
# 415  4.519774  2.259887     1.129944      1.412429
# 416  2.124834  1.062417     0.531208      0.664011
# 418  2.972399  1.486200     3.609342      0.849257
# 424  4.347826  3.260870     2.173913      1.630435
# 425  4.081633  3.061224     2.040816      1.530612
#
# [211 rows x 23 columns]

# %%
col_1 = df_1.columns[6:]
data_1 = df_1[col_1].values

# %%
pca_transformed_1 = pca.fit_transform(data_1)
df_1['pca_x'] = pca_transformed_1[:,0]
df_1['pca_y'] = pca_transformed_1[:,1]
df_1
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   5.328145  23.216602
# 2    종로구    삼청동  1111054000   2739  1.49     1838   7.818792  15.436242
# 3    종로구    부암동  1111055000   9782  2.27     4309   3.819383  18.942731
# 4    종로구    평창동  1111056000  18329  8.87     2066   3.926719   2.480271
# 5    종로구    무악동  1111057000   8297  0.36    23047  13.416667  36.111111
# ..   ...    ...         ...    ...   ...      ...        ...        ...
# 415  강동구   암사2동  1174058000  15252  1.18    12925   9.138418  38.135593
# 416  강동구   암사3동  1174059000  17947  2.51     7150   5.407703  17.928287
# 418  강동구   천호2동  1174061000  33753  1.57    21499   9.121019  56.900212
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.945652  36.413043
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARANTING       MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   5.692607   2.853437  1249.027237           0.0
# 2     4.496644     9.315436   1.006711   7.382550   459.060403           0.0
# 3     1.682819     4.854626   9.030837   2.202643  1138.766520           0.0
# 4     1.517475     1.312289   2.213078   1.127396   518.263811           0.0
# 5    13.888889     9.388889  43.888889  36.111111  5061.111111           0.0
# ..         ...          ...        ...        ...          ...           ...
# 415  24.271186    13.604520  40.528249  11.581921  3988.135593           0.0
# 416  11.410359     6.395750  19.053121   5.444887  1699.203187           0.0
# 418  39.966030    20.125265  19.641189  17.409766  7136.942675           0.0
# 424  15.467391    12.885870  31.016304   0.000000    35.869565           0.0
# 425  14.520408    12.096939  29.117347   0.000000  7143.877551           0.0
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000                  1.0     0.389105
# 2    0.000000       0.671141  0.000000                  1.0     0.000000
# 3    0.000000       0.000000  0.000000                  1.0     0.000000
# 4    0.000000       0.112740  0.000000                  4.0     0.000000
# 5    0.000000       0.000000  0.000000                  1.0     0.000000
# ..        ...            ...       ...                  ...          ...
# 415  1.129944       0.282486  0.000000                  2.0     0.282486
# 416  0.531208       0.132802  0.000000                  3.0     0.132802
# 418  1.273885       0.849257  0.212314                  3.0     2.760085
# 424  0.000000       0.000000  0.543478                  1.0     0.000000
# 425  0.000000       0.000000  0.510204                  1.0     0.000000
#
#       GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM        pca_x      pca_y
# 0    0.000000  0.000000     0.389105      0.778210 -3843.689897   0.556944
# 2    2.013423  0.000000     0.671141      0.000000 -4633.661513  -1.687504
# 3    0.881057  0.881057     2.202643      1.321586 -3953.969750  -3.486087
# 4    0.563698  0.563698     0.000000      0.000000 -4574.557128 -16.812806
# 5    0.000000  2.777778     2.777778      0.000000   -31.415356  -0.205085
# ..        ...       ...          ...           ...          ...        ...
# 415  4.519774  2.259887     1.129944      1.412429 -1104.409777   5.900414
# 416  2.124834  1.062417     0.531208      0.664011 -3393.492957  -5.318095
# 418  2.972399  1.486200     3.609342      0.849257  2044.436721  10.746285
# 424  4.347826  3.260870     2.173913      1.630435 -5056.679485  22.210189
# 425  4.081633  3.061224     2.040816      1.530612  2051.179963 -17.659890
#
# [211 rows x 25 columns]

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_1)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 3(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
# label
label_1 = kmeans.fit(pca_transformed_1)
# Getting unique labels
u_labels = np.unique(label_1)

# %%
df_1['km_cluster'] = kmeans.labels_
df_1.groupby('km_cluster').count()
# Out:
#             GU  DONG  DONG_CODE  POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# km_cluster
# 0           59    59         59   59    59       59         59        59
# 1           72    72         72   72    72       72         72        72
# 2           80    80         80   80    80       80         80        80
#
#             HEALTH  CONVENIENCE  EDUCATION  PARANTING  MZ_NUM  COLIVING_NUM  \
# km_cluster
# 0               59           59         59         59      59            59
# 1               72           72         72         72      72            72
# 2               80           80         80         80      80            80
#
#             KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# km_cluster
# 0                 59             59      59                   59           59
# 1                 72             72      72                   72           72
# 2                 80             80      80                   80           80
#
#             GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  pca_x  pca_y
# km_cluster
# 0                59        59           59            59     59     59
# 1                72        72           72            72     72     72
# 2                80        80           80            80     80     80

# %%
df_1['pca_x'] = pca_transformed_1[:,0]
df_1['pca_y'] = pca_transformed_1[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_1['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_1[df_1['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_1.loc[markers[i], 'pca_x'], y = df_1.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2'])
plt.show()

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed_1)      
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 211 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
score = silhouette_score(data_1,df_1['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
# Out:
# Silhouette Score :  0.553

# %% [markdown]
# #### 2.2.3 km_cluster == 2

# %% [markdown]
# - Elbow 관측

# %%
df_2 = df[df['km_cluster'] == 2][tmp_df.columns]
df_2
# Out:
#        GU  DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT    SECURITY  \
# 6     종로구   교남동  1111058000  10203  0.35    29151  38.257143   28.571429
# 17     중구   소공동  1114052000   3367  0.95     3544  26.105263   86.315789
# 18     중구   회현동  1114054000   5432  0.84     6467  27.750000  115.476190
# 19     중구    명동  1114055000   3742  0.99     3780  32.646465  125.757576
# 22     중구   광희동  1114059000   6340  0.74     8568  24.608108  122.972973
# 23     중구  을지로동  1114060500   1914  0.60     3190  30.533333   98.333333
# 30     중구   황학동  1114067000  13444  0.33    40739  17.090909  181.818182
# 73    광진구  자양1동  1121582000  23134  0.57    40586  19.017544   70.614035
# 77    광진구  구의1동  1121585000  22139  0.56    39534  15.190476   94.642857
# 112   성북구   동선동  1129057500  16115  0.73    22075  16.041096  132.648402
# 117   성북구  정릉1동  1129062000  18377  0.44    41766  28.212121  258.901515
# 122   성북구  길음2동  1129068500  16780  0.58    28931  24.287356  128.160920
# 214   마포구   서교동  1144066000  26549  1.65    16090  26.575758   76.969697
# 224   양천구   목3동  1147053000  21977  0.53    41466  17.943396   67.547170
# 225   양천구   목4동  1147054000  25544  0.57    44814  15.052632   62.807018
# 235   양천구  신정2동  1147063000  19596  0.52    37685  15.474359   50.961538
# 241   강서구  등촌1동  1150052000  24436  0.64    38181  20.588542   44.791667
# 245   강서구  화곡2동  1150055000  18096  0.45    40213  32.300000   90.555556
# 264   구로구  구로4동  1153055000  23745  0.46    51620  29.421739  321.304348
# 276   금천구   가산동  1154551000  26179  2.52    10388  28.404762   37.301587
# 287  영등포구  영등포동  1156053500  29901  1.26    23731  16.150794  131.349206
# 320   관악구   청림동  1162054500  15214  0.30    50713  20.755556  124.074074
# 326   관악구   중앙동  1162061500  15487  0.39    39710  20.735043   95.441595
# 340   서초구  서초1동  1165051000  20711  1.42    14585  17.080986   29.753521
# 341   서초구  서초2동  1165052000  26595  1.24    21448  24.060484   34.072581
# 343   서초구  서초4동  1165053100  31089  0.88    35328  34.960227   48.011364
# 359   강남구  논현1동  1168052100  22702  1.25    18162   6.672000  202.000000
# 360   강남구  논현2동  1168053100  21331  1.47    14511   3.775510  171.768707
# 364   강남구  삼성2동  1168059000  30692  1.24    24752   8.564516  121.370968
# 365   강남구  대치1동  1168060000  24199  0.79    30632  14.594937  116.772152
# 367   강남구  대치4동  1168063000  20079  0.73    27505  11.972603  126.369863
# 368   강남구  역삼1동  1168064000  36590  2.35    15570  12.225532   91.914894
# 369   강남구  역삼2동  1168065000  36378  1.15    31633  14.469565  187.826087
# 378   강남구  일원2동  1168074000  17585  1.24    14181   7.504032  161.491935
# 386   송파구  방이1동  1171056100  15766  0.50    31532   9.853333   20.666667
# 391   송파구  송파2동  1171059000  19283  0.53    36383  11.037736   21.698113
# 397   송파구  문정1동  1171064100  20198  0.56    36068  13.184524    9.523810
# 410   강동구  명일1동  1174053000  25941  0.61    42526  17.524590   48.360656
# 420   강동구  성내1동  1174064000  20045  0.58    34560   9.212644   91.954023
#
#          HEALTH  CONVENIENCE   EDUCATION   PARANTING        MZ_NUM  \
# 6     56.628571    22.914286   40.571429  102.857143   8122.857143
# 17    63.778947    52.884211    8.310526   32.105263   1150.526316
# 18    73.321429    60.148810    1.267857   45.833333   1413.095238
# 19   144.606061   111.616162   14.964646   44.444444   1235.353535
# 22    47.500000    75.533784    3.405405   26.351351   3525.675676
# 23    73.866667    75.766667    1.166667   46.666667   1106.666667
# 30    67.333333    42.151515    6.363636   81.818182  16354.545455
# 73    68.412281    40.109649   69.535088   45.614035  14417.543860
# 77    68.428571    50.142857  108.273810   66.666667  16314.285714
# 112   86.625571    39.591324  105.773973   14.840183  10345.205479
# 117   91.250000    58.384470  171.765152  112.689394  11086.363636
# 122   70.298851    39.436782  105.459770   75.287356   7715.517241
# 214  100.933333    67.621212   92.254545   10.606061   7865.454545
# 224  103.766038    40.713208  283.524528   97.358491  13743.396226
# 225   96.484211    37.856140  263.628070   90.526316  11977.192982
# 235   76.115385    33.913462  202.121795   97.435897   7873.076923
# 241   59.416667    38.677083   75.953125   88.020833  17625.000000
# 245   86.344444    44.736111   70.361111   93.055556  12144.444444
# 264  100.226087    63.595652   59.521739  154.782609  14132.608696
# 276   31.087302    52.000000   10.000000   11.507937   5305.952381
# 287   91.293651    65.218254   43.837302  103.968254  12286.507937
# 320  128.251852    70.011111  102.625926  125.555556  14490.000000
# 326   98.655271    53.854701   78.943020   96.581197  19633.333333
# 340   96.838028    35.556338   65.920775   51.232394   4512.676056
# 341  110.895161    40.717742   75.489919   58.669355   6994.354839
# 343  156.261364    57.375000  106.372159   82.670455   7989.772727
# 359  143.272000    65.124000   51.308000    7.200000   8179.200000
# 360  121.829932    55.377551   43.629252    6.122449   5341.496599
# 364   73.120968    49.935484   41.346774   16.935484   7098.387097
# 365   89.411392    44.037975  361.287975   28.797468   4789.873418
# 367   96.760274    47.657534  390.982877   31.164384   9175.342466
# 368  103.276596    57.776596   58.589362   15.744681   7751.489362
# 369  211.043478   118.065217  119.726087   32.173913   8150.434783
# 378   85.536290    41.177419  276.032258   33.870968   3466.935484
# 386   79.226667    32.766667  132.046667   40.000000   9256.000000
# 391   82.226415    33.575472  111.915094   43.396226  10164.150943
# 397   49.571429    41.410714   69.523810   40.476190  11748.214286
# 410  112.967213    30.540984  201.254098   23.770492  11513.114754
# 420   97.471264    51.431034   78.545977   35.632184  10234.482759
#
#      COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  \
# 6        0.000000  2.857143      11.428571  0.000000                  1.0
# 17       3.157895  0.000000       9.473684  0.000000                  1.0
# 18       1.190476  0.000000      11.309524  0.000000                  1.0
# 19       3.030303  0.000000      18.686869  3.030303                  1.0
# 22       5.405405  1.351351       4.729730  0.000000                  1.0
# 23       0.000000  0.000000       5.000000  0.000000                  1.0
# 30       0.000000  3.030303       3.030303  0.000000                  1.0
# 73       0.000000  2.192982       2.192982  0.438596                  3.0
# 77       0.000000  0.000000       1.785714  0.000000                  2.0
# 112      0.000000  2.968037       2.968037  0.000000                  1.0
# 117      0.000000  2.272727       1.893939  0.000000                  1.0
# 122      0.000000  2.298851       2.298851  0.000000                  1.0
# 214      1.818182  0.606061       5.151515  0.606061                  1.0
# 224      0.000000  1.886792       3.773585  0.377358                  4.0
# 225      0.000000  1.754386       3.508772  0.350877                  4.0
# 235      0.000000  1.282051       1.282051  0.320513                  4.0
# 241      1.562500  1.041667       2.604167  0.520833                  3.0
# 245      0.000000  1.388889       1.666667  0.277778                  4.0
# 264      0.000000  0.869565       2.608696  0.434783                  3.0
# 276      0.000000  1.587302       3.571429  1.587302                  3.0
# 287      0.793651  2.777778       6.349206  0.793651                  1.0
# 320      0.000000  1.111111       2.592593  0.000000                  3.0
# 326      0.000000  0.854701       1.994302  0.000000                  3.0
# 340      2.112676  0.704225       3.697183  0.528169                  3.0
# 341      1.612903  0.806452       4.233871  0.604839                  3.0
# 343      0.000000  1.136364       5.965909  0.852273                  2.0
# 359      0.000000  0.000000       4.000000  0.800000                  1.0
# 360      0.000000  0.000000       3.401361  0.680272                  1.0
# 364      0.806452  0.000000       6.048387  0.806452                  1.0
# 365      0.000000  0.316456       5.063291  0.316456                  1.0
# 367      0.000000  0.342466       5.479452  0.342466                  1.0
# 368      1.276596  0.425532       5.106383  0.425532                  1.0
# 369      0.000000  0.869565      10.434783  0.869565                  1.0
# 378      0.000000  0.403226       3.427419  0.201613                  1.0
# 386      0.000000  4.000000       2.666667  0.000000                  2.0
# 391      0.000000  0.000000       1.886792  0.943396                  1.0
# 397      0.000000  1.190476       2.976190  0.000000                  2.0
# 410      0.000000  2.459016       2.459016  0.000000                  1.0
# 420      0.000000  1.149425       2.298851  0.000000                  1.0
#
#      LEISURE_NUM    GYM_NUM   GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM
# 6       0.000000   5.714286   0.000000     0.000000      2.857143
# 17      0.000000   6.842105   3.157895     8.947368      0.000000
# 18      0.000000   5.952381   0.000000     8.928571      0.000000
# 19      1.010101  18.181818   3.030303     7.070707      0.000000
# 22      6.756757   1.351351   2.702703     7.432432      0.675676
# 23      1.666667   3.333333   5.000000     3.333333      5.000000
# 30     12.121212  18.181818   9.090909     6.060606      9.090909
# 73      3.070175  17.543860   9.210526    10.526316      3.947368
# 77      1.785714  24.404762  10.714286     5.357143      2.380952
# 112     8.219178  15.753425   2.511416     7.762557      4.337900
# 117     0.757576  13.636364   9.090909    11.553030      6.060606
# 122     1.724138  10.919540   4.597701     9.770115      6.321839
# 214     9.090909  23.939394   2.424242    14.545455      5.757576
# 224     3.018868  24.905660   9.433962     9.811321      7.924528
# 225     2.807018  23.157895   8.771930     9.122807      7.368421
# 235     1.602564  15.705128   8.653846     8.333333      5.128205
# 241     1.562500  19.270833   9.895833     7.812500      2.604167
# 245     6.388889  15.555556   4.444444    10.555556      5.000000
# 264     4.347826  16.956522   8.695652    16.956522      3.043478
# 276     3.174603   9.523810   5.158730     7.539683      0.396825
# 287     9.523810  11.111111   3.174603     8.730159      4.365079
# 320     1.851852  26.296296   9.629630    12.962963      5.555556
# 326     1.424501  20.227920   7.407407     9.971510      4.273504
# 340     1.760563  21.126761  11.795775     6.514085      2.112676
# 341     2.016129  24.193548  13.508065     7.459677      2.419355
# 343     2.840909  34.090909  19.034091    10.511364      3.409091
# 359     0.800000  30.800000  19.200000     9.600000      4.400000
# 360     0.680272  26.190476  16.326531     8.163265      3.741497
# 364     1.612903  15.322581  15.725806     7.661290      3.225806
# 365     0.316456  18.354430  16.455696     6.329114      2.531646
# 367     0.342466  19.863014  17.808219     6.849315      2.739726
# 368     2.340426  19.148936  13.829787     8.085106      3.191489
# 369     4.782609  39.130435  28.260870    16.521739      6.521739
# 378     0.403226  15.524194  15.927419     6.854839      4.032258
# 386     1.333333  20.666667  11.333333     7.333333      4.000000
# 391     0.000000  29.245283   8.490566     5.660377      8.490566
# 397     1.190476  20.833333   9.523810    10.119048      4.761905
# 410     2.459016  13.934426   9.836066     9.016393      3.278689
# 420     2.873563  17.241379   8.045977    11.494253      4.597701

# %%
col_2 = df_2.columns[6:-2]
data_2 = df_2[col_2].values

# %%
pca_transformed_2 = pca.fit_transform(data_2)
df_2['pca_x'] = pca_transformed_2[:,0]
df_2['pca_y'] = pca_transformed_2[:,1]
df_2
# Out:
#        GU  DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT    SECURITY  \
# 6     종로구   교남동  1111058000  10203  0.35    29151  38.257143   28.571429
# 17     중구   소공동  1114052000   3367  0.95     3544  26.105263   86.315789
# 18     중구   회현동  1114054000   5432  0.84     6467  27.750000  115.476190
# 19     중구    명동  1114055000   3742  0.99     3780  32.646465  125.757576
# 22     중구   광희동  1114059000   6340  0.74     8568  24.608108  122.972973
# 23     중구  을지로동  1114060500   1914  0.60     3190  30.533333   98.333333
# 30     중구   황학동  1114067000  13444  0.33    40739  17.090909  181.818182
# 73    광진구  자양1동  1121582000  23134  0.57    40586  19.017544   70.614035
# 77    광진구  구의1동  1121585000  22139  0.56    39534  15.190476   94.642857
# 112   성북구   동선동  1129057500  16115  0.73    22075  16.041096  132.648402
# 117   성북구  정릉1동  1129062000  18377  0.44    41766  28.212121  258.901515
# 122   성북구  길음2동  1129068500  16780  0.58    28931  24.287356  128.160920
# 214   마포구   서교동  1144066000  26549  1.65    16090  26.575758   76.969697
# 224   양천구   목3동  1147053000  21977  0.53    41466  17.943396   67.547170
# 225   양천구   목4동  1147054000  25544  0.57    44814  15.052632   62.807018
# 235   양천구  신정2동  1147063000  19596  0.52    37685  15.474359   50.961538
# 241   강서구  등촌1동  1150052000  24436  0.64    38181  20.588542   44.791667
# 245   강서구  화곡2동  1150055000  18096  0.45    40213  32.300000   90.555556
# 264   구로구  구로4동  1153055000  23745  0.46    51620  29.421739  321.304348
# 276   금천구   가산동  1154551000  26179  2.52    10388  28.404762   37.301587
# 287  영등포구  영등포동  1156053500  29901  1.26    23731  16.150794  131.349206
# 320   관악구   청림동  1162054500  15214  0.30    50713  20.755556  124.074074
# 326   관악구   중앙동  1162061500  15487  0.39    39710  20.735043   95.441595
# 340   서초구  서초1동  1165051000  20711  1.42    14585  17.080986   29.753521
# 341   서초구  서초2동  1165052000  26595  1.24    21448  24.060484   34.072581
# 343   서초구  서초4동  1165053100  31089  0.88    35328  34.960227   48.011364
# 359   강남구  논현1동  1168052100  22702  1.25    18162   6.672000  202.000000
# 360   강남구  논현2동  1168053100  21331  1.47    14511   3.775510  171.768707
# 364   강남구  삼성2동  1168059000  30692  1.24    24752   8.564516  121.370968
# 365   강남구  대치1동  1168060000  24199  0.79    30632  14.594937  116.772152
# 367   강남구  대치4동  1168063000  20079  0.73    27505  11.972603  126.369863
# 368   강남구  역삼1동  1168064000  36590  2.35    15570  12.225532   91.914894
# 369   강남구  역삼2동  1168065000  36378  1.15    31633  14.469565  187.826087
# 378   강남구  일원2동  1168074000  17585  1.24    14181   7.504032  161.491935
# 386   송파구  방이1동  1171056100  15766  0.50    31532   9.853333   20.666667
# 391   송파구  송파2동  1171059000  19283  0.53    36383  11.037736   21.698113
# 397   송파구  문정1동  1171064100  20198  0.56    36068  13.184524    9.523810
# 410   강동구  명일1동  1174053000  25941  0.61    42526  17.524590   48.360656
# 420   강동구  성내1동  1174064000  20045  0.58    34560   9.212644   91.954023
#
#          HEALTH  CONVENIENCE   EDUCATION   PARANTING        MZ_NUM  \
# 6     56.628571    22.914286   40.571429  102.857143   8122.857143
# 17    63.778947    52.884211    8.310526   32.105263   1150.526316
# 18    73.321429    60.148810    1.267857   45.833333   1413.095238
# 19   144.606061   111.616162   14.964646   44.444444   1235.353535
# 22    47.500000    75.533784    3.405405   26.351351   3525.675676
# 23    73.866667    75.766667    1.166667   46.666667   1106.666667
# 30    67.333333    42.151515    6.363636   81.818182  16354.545455
# 73    68.412281    40.109649   69.535088   45.614035  14417.543860
# 77    68.428571    50.142857  108.273810   66.666667  16314.285714
# 112   86.625571    39.591324  105.773973   14.840183  10345.205479
# 117   91.250000    58.384470  171.765152  112.689394  11086.363636
# 122   70.298851    39.436782  105.459770   75.287356   7715.517241
# 214  100.933333    67.621212   92.254545   10.606061   7865.454545
# 224  103.766038    40.713208  283.524528   97.358491  13743.396226
# 225   96.484211    37.856140  263.628070   90.526316  11977.192982
# 235   76.115385    33.913462  202.121795   97.435897   7873.076923
# 241   59.416667    38.677083   75.953125   88.020833  17625.000000
# 245   86.344444    44.736111   70.361111   93.055556  12144.444444
# 264  100.226087    63.595652   59.521739  154.782609  14132.608696
# 276   31.087302    52.000000   10.000000   11.507937   5305.952381
# 287   91.293651    65.218254   43.837302  103.968254  12286.507937
# 320  128.251852    70.011111  102.625926  125.555556  14490.000000
# 326   98.655271    53.854701   78.943020   96.581197  19633.333333
# 340   96.838028    35.556338   65.920775   51.232394   4512.676056
# 341  110.895161    40.717742   75.489919   58.669355   6994.354839
# 343  156.261364    57.375000  106.372159   82.670455   7989.772727
# 359  143.272000    65.124000   51.308000    7.200000   8179.200000
# 360  121.829932    55.377551   43.629252    6.122449   5341.496599
# 364   73.120968    49.935484   41.346774   16.935484   7098.387097
# 365   89.411392    44.037975  361.287975   28.797468   4789.873418
# 367   96.760274    47.657534  390.982877   31.164384   9175.342466
# 368  103.276596    57.776596   58.589362   15.744681   7751.489362
# 369  211.043478   118.065217  119.726087   32.173913   8150.434783
# 378   85.536290    41.177419  276.032258   33.870968   3466.935484
# 386   79.226667    32.766667  132.046667   40.000000   9256.000000
# 391   82.226415    33.575472  111.915094   43.396226  10164.150943
# 397   49.571429    41.410714   69.523810   40.476190  11748.214286
# 410  112.967213    30.540984  201.254098   23.770492  11513.114754
# 420   97.471264    51.431034   78.545977   35.632184  10234.482759
#
#      COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  \
# 6        0.000000  2.857143      11.428571  0.000000                  1.0
# 17       3.157895  0.000000       9.473684  0.000000                  1.0
# 18       1.190476  0.000000      11.309524  0.000000                  1.0
# 19       3.030303  0.000000      18.686869  3.030303                  1.0
# 22       5.405405  1.351351       4.729730  0.000000                  1.0
# 23       0.000000  0.000000       5.000000  0.000000                  1.0
# 30       0.000000  3.030303       3.030303  0.000000                  1.0
# 73       0.000000  2.192982       2.192982  0.438596                  3.0
# 77       0.000000  0.000000       1.785714  0.000000                  2.0
# 112      0.000000  2.968037       2.968037  0.000000                  1.0
# 117      0.000000  2.272727       1.893939  0.000000                  1.0
# 122      0.000000  2.298851       2.298851  0.000000                  1.0
# 214      1.818182  0.606061       5.151515  0.606061                  1.0
# 224      0.000000  1.886792       3.773585  0.377358                  4.0
# 225      0.000000  1.754386       3.508772  0.350877                  4.0
# 235      0.000000  1.282051       1.282051  0.320513                  4.0
# 241      1.562500  1.041667       2.604167  0.520833                  3.0
# 245      0.000000  1.388889       1.666667  0.277778                  4.0
# 264      0.000000  0.869565       2.608696  0.434783                  3.0
# 276      0.000000  1.587302       3.571429  1.587302                  3.0
# 287      0.793651  2.777778       6.349206  0.793651                  1.0
# 320      0.000000  1.111111       2.592593  0.000000                  3.0
# 326      0.000000  0.854701       1.994302  0.000000                  3.0
# 340      2.112676  0.704225       3.697183  0.528169                  3.0
# 341      1.612903  0.806452       4.233871  0.604839                  3.0
# 343      0.000000  1.136364       5.965909  0.852273                  2.0
# 359      0.000000  0.000000       4.000000  0.800000                  1.0
# 360      0.000000  0.000000       3.401361  0.680272                  1.0
# 364      0.806452  0.000000       6.048387  0.806452                  1.0
# 365      0.000000  0.316456       5.063291  0.316456                  1.0
# 367      0.000000  0.342466       5.479452  0.342466                  1.0
# 368      1.276596  0.425532       5.106383  0.425532                  1.0
# 369      0.000000  0.869565      10.434783  0.869565                  1.0
# 378      0.000000  0.403226       3.427419  0.201613                  1.0
# 386      0.000000  4.000000       2.666667  0.000000                  2.0
# 391      0.000000  0.000000       1.886792  0.943396                  1.0
# 397      0.000000  1.190476       2.976190  0.000000                  2.0
# 410      0.000000  2.459016       2.459016  0.000000                  1.0
# 420      0.000000  1.149425       2.298851  0.000000                  1.0
#
#      LEISURE_NUM    GYM_NUM   GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  \
# 6       0.000000   5.714286   0.000000     0.000000      2.857143
# 17      0.000000   6.842105   3.157895     8.947368      0.000000
# 18      0.000000   5.952381   0.000000     8.928571      0.000000
# 19      1.010101  18.181818   3.030303     7.070707      0.000000
# 22      6.756757   1.351351   2.702703     7.432432      0.675676
# 23      1.666667   3.333333   5.000000     3.333333      5.000000
# 30     12.121212  18.181818   9.090909     6.060606      9.090909
# 73      3.070175  17.543860   9.210526    10.526316      3.947368
# 77      1.785714  24.404762  10.714286     5.357143      2.380952
# 112     8.219178  15.753425   2.511416     7.762557      4.337900
# 117     0.757576  13.636364   9.090909    11.553030      6.060606
# 122     1.724138  10.919540   4.597701     9.770115      6.321839
# 214     9.090909  23.939394   2.424242    14.545455      5.757576
# 224     3.018868  24.905660   9.433962     9.811321      7.924528
# 225     2.807018  23.157895   8.771930     9.122807      7.368421
# 235     1.602564  15.705128   8.653846     8.333333      5.128205
# 241     1.562500  19.270833   9.895833     7.812500      2.604167
# 245     6.388889  15.555556   4.444444    10.555556      5.000000
# 264     4.347826  16.956522   8.695652    16.956522      3.043478
# 276     3.174603   9.523810   5.158730     7.539683      0.396825
# 287     9.523810  11.111111   3.174603     8.730159      4.365079
# 320     1.851852  26.296296   9.629630    12.962963      5.555556
# 326     1.424501  20.227920   7.407407     9.971510      4.273504
# 340     1.760563  21.126761  11.795775     6.514085      2.112676
# 341     2.016129  24.193548  13.508065     7.459677      2.419355
# 343     2.840909  34.090909  19.034091    10.511364      3.409091
# 359     0.800000  30.800000  19.200000     9.600000      4.400000
# 360     0.680272  26.190476  16.326531     8.163265      3.741497
# 364     1.612903  15.322581  15.725806     7.661290      3.225806
# 365     0.316456  18.354430  16.455696     6.329114      2.531646
# 367     0.342466  19.863014  17.808219     6.849315      2.739726
# 368     2.340426  19.148936  13.829787     8.085106      3.191489
# 369     4.782609  39.130435  28.260870    16.521739      6.521739
# 378     0.403226  15.524194  15.927419     6.854839      4.032258
# 386     1.333333  20.666667  11.333333     7.333333      4.000000
# 391     0.000000  29.245283   8.490566     5.660377      8.490566
# 397     1.190476  20.833333   9.523810    10.119048      4.761905
# 410     2.459016  13.934426   9.836066     9.016393      3.278689
# 420     2.873563  17.241379   8.045977    11.494253      4.597701
#
#             pca_x       pca_y
# 6    -1011.238729  -61.793137
# 17   -7983.859448  -76.787916
# 18   -7721.250217  -85.334666
# 19   -7899.023721  -69.935364
# 22   -5608.782605  -91.137340
# 23   -8027.698213  -84.973448
# 30    7220.237234 -120.804503
# 73    5283.214452  -49.442123
# 77    7180.129175  -16.971579
# 112   1210.929815   -2.828588
# 117   1952.711678   55.928789
# 122  -1418.472054    2.255084
# 214  -1268.907030   -9.068905
# 224   4609.859947  167.182265
# 225   2843.600740  152.036968
# 235  -1260.595590  100.877624
# 241   8490.812199  -51.809331
# 245   3010.347873  -43.265146
# 264   4998.823926  -65.662902
# 276  -3828.588846  -86.583685
# 287   3152.383020  -71.679074
# 320   5356.084595  -16.736724
# 326  10499.166454  -54.094510
# 340  -4621.525039  -23.544377
# 341  -2139.829486  -20.380216
# 343  -1144.258572    8.895887
# 359   -955.214627  -49.933828
# 360  -3792.907689  -50.043608
# 364  -2036.022906  -58.798588
# 365  -4343.601063  267.061995
# 367     41.898285  285.027072
# 368  -1382.918487  -41.370894
# 369   -983.772383   19.602639
# 378  -5666.696278  184.630513
# 386    121.866167   29.282898
# 391   1029.968561    6.969763
# 397   2613.869789  -41.667626
# 410   2379.071510   93.295639
# 420   1100.187561  -28.399058

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_2)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 3(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
# label
label_2 = kmeans.fit(pca_transformed_2)
# Getting unique labels
u_labels = np.unique(label_2)

# %%
df_2['km_cluster'] = kmeans.labels_
df_2.groupby('km_cluster').count()
# Out:
#             GU  DONG  DONG_CODE  POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# km_cluster
# 0           21    21         21   21    21       21         21        21
# 1            8     8          8    8     8        8          8         8
# 2           10    10         10   10    10       10         10        10
#
#             HEALTH  CONVENIENCE  EDUCATION  PARANTING  MZ_NUM  COLIVING_NUM  \
# km_cluster
# 0               21           21         21         21      21            21
# 1                8            8          8          8       8             8
# 2               10           10         10         10      10            10
#
#             KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# km_cluster
# 0                 21             21      21                   21           21
# 1                  8              8       8                    8            8
# 2                 10             10      10                   10           10
#
#             GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  pca_x  pca_y
# km_cluster
# 0                21        21           21            21     21     21
# 1                 8         8            8             8      8      8
# 2                10        10           10            10     10     10

# %%
df_2['pca_x'] = pca_transformed_2[:,0]
df_2['pca_y'] = pca_transformed_2[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_2['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_2[df_2['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_2.loc[markers[i], 'pca_x'], y = df_2.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2','cluster3'])
plt.show()

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed_2)      
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 39 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
score = silhouette_score(data_2,df_2['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
# Out:
# Silhouette Score :  0.574
