# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.preprocessing import RobustScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA
from yellowbrick.cluster import SilhouetteVisualizer
from scipy.stats import skew, kurtosis

import warnings

warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## 1. 데이터 입력

# %% [markdown]
# ### 1.1 행정동, 밀도 데이터 로드 및 병합

# %%
tmp_df = pd.read_csv('../data/행정동_최종ver.csv')
pd.set_option('display.max_columns',35)
# tmp_df
tmp_df.rename(columns={'Unnamed: 0':'index'},inplace=True)
tmp_df.set_index('index',inplace=True)

# %%
tmp_df.rename(columns={'MZ_POP_CNT':'MZ_NUM'},inplace=True)
tmp_df.rename(columns={'VEGAN_CNT':'VEGAN_NUM'},inplace=True)
tmp_df
# Out:
#         GU   DONG   DONG_CODE  ACADEMY_NUM  KINDER_NUM  FIRE_NUM  ELE_SCH_NUM  \
# index
# 0      종로구  청운효자동  1111051500    18.000000    0.000000       1.0     2.000000
# 1      종로구    사직동  1111053000    19.000000   10.000000       0.0     2.000000
# 2      종로구    삼청동  1111054000     2.000000   10.000000       0.0     0.000000
# 3      종로구    부암동  1111055000    24.000000    0.000000       1.0     4.000000
# 4      종로구    평창동  1111056000    28.000000    0.000000       0.0     0.000000
# ...    ...    ...         ...          ...         ...       ...          ...
# 421    강동구   성내2동  1174065000    63.333333   16.666667       1.0     1.333333
# 422    강동구   성내3동  1174066000    63.333333   16.666667       1.0     1.333333
# 423    강동구     길동  1174068500   100.000000   20.000000       1.0     6.000000
# 424    강동구   둔촌1동  1174069000    38.000000    0.000000       0.0     2.000000
# 425    강동구   둔촌2동  1174070000    38.000000    0.000000       0.0     2.000000
#
#        MID_SCH_NUM  HIGH_SCH_NUM    CCTV_NUM  POLICE_NUM   BIKE_NUM  \
# index
# 0         2.000000           3.0   56.666667    2.000000   5.666667
# 1         0.000000           0.0   41.666667    3.000000  11.666667
# 2         1.000000           1.0   22.000000    1.000000   7.000000
# 3         1.000000           1.0   41.000000    1.000000   5.000000
# 4         0.000000           1.0   21.000000    1.000000   7.000000
# ...            ...           ...         ...         ...        ...
# 421       0.333333           0.0   52.000000    0.333333   6.000000
# 422       0.333333           0.0   52.000000    0.333333   6.000000
# 423       1.000000           0.0  119.000000    0.000000   9.000000
# 424       1.500000           1.0   32.500000    1.000000   5.500000
# 425       1.500000           1.0   32.500000    1.000000   5.500000
#
#        CAR_SHR_NUM  SUBWAY_NUM  SAFE_DLVR_NUM  DPTM_NUM  ANI_HSPT_NUM  ...  \
# index                                                                  ...
# 0         1.000000    0.333333       1.000000       0.0      2.000000  ...
# 1         5.000000    1.333333       0.000000       0.0      1.000000  ...
# 2         1.000000    1.000000       0.000000       0.0      0.000000  ...
# 3         5.000000    0.000000       0.000000       0.0      3.000000  ...
# 4         0.000000    0.000000       0.000000       0.0      0.000000  ...
# ...            ...         ...            ...       ...           ...  ...
# 421       6.666667    0.333333       0.666667       0.0      2.666667  ...
# 422       6.666667    0.333333       0.666667       0.0      2.666667  ...
# 423      10.000000    1.000000       1.000000       0.0      8.000000  ...
# 424       2.000000    0.500000       0.000000       0.0      1.500000  ...
# 425       2.000000    0.500000       0.000000       0.0      1.500000  ...
#
#        KIDS_NUM  SPORT_NUM  GYM_NUM  GOLF_NUM  STARBUCKS_NUM  MC_NUM  \
# index
# 0      0.000000        0.0      0.0  0.000000       0.333333     0.0
# 1      0.000000        0.0     18.0  3.000000       7.333333     0.0
# 2      0.000000        1.0      3.0  0.000000       1.000000     0.0
# 3      0.000000        0.0      2.0  2.000000       0.000000     0.0
# 4      0.000000        0.0      5.0  5.000000       1.000000     0.0
# ...         ...        ...      ...       ...            ...     ...
# 421    0.666667        0.0     10.0  4.666667       1.333333     0.0
# 422    0.666667        0.0     10.0  4.666667       1.333333     0.0
# 423    1.000000        0.0     18.0  9.000000       2.000000     0.0
# 424    0.000000        0.0      4.0  3.000000       0.000000     0.5
# 425    0.000000        0.0      4.0  3.000000       0.000000     0.5
#
#          CON_NUM  NOISE_VIBRATION_NUM  CHILD_MED_NUM    CAFE_NUM  PARK_NUM  \
# index
# 0       4.000000         18816.000000       7.333333   39.666667  1.666667
# 1      20.000000         22848.000000      10.333333  100.666667  2.666667
# 2       2.000000         14112.000000       1.000000   52.000000  1.000000
# 3       8.000000          6048.000000       5.000000   30.000000  1.000000
# 4       6.000000          4032.000000      10.000000   36.000000  0.000000
# ...          ...                  ...            ...         ...       ...
# 421    38.666667          1442.333333       4.000000   47.666667  0.000000
# 422    38.666667          1442.333333       4.000000   47.666667  0.000000
# 423    76.000000          4327.000000      10.000000   63.000000  1.000000
# 424    17.000000          2163.500000       0.000000   17.500000  1.000000
# 425    17.000000          2163.500000       0.000000   17.500000  1.000000
#
#        HOSPITAL_NUM  BUS_CNT  VEGAN_NUM  RETAIL_NUM  COLIVING_NUM  MZ_NUM
# index
# 0         11.666667     14.0   5.000000    0.000000           0.0    3210
# 1         74.666667     16.0   8.000000    2.000000           1.0    2749
# 2          7.000000     11.0   6.000000    0.000000           0.0     684
# 3          4.000000      9.0   1.000000    0.000000           0.0    2585
# 4         14.000000     37.0   2.000000    0.000000           0.0    4597
# ...             ...      ...        ...         ...           ...     ...
# 421       59.333333     11.0   2.333333    3.333333           0.0    8130
# 422       59.333333      9.0   2.333333    3.333333           0.0    7120
# 423      120.000000     28.0   1.000000    8.000000           0.0   14486
# 424       14.500000      4.0   0.500000    0.000000           0.0      33
# 425       14.500000     20.0   0.500000    0.000000           0.0    7001
#
# [426 rows x 36 columns]

# %%
tmp_df.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'ACADEMY_NUM', 'KINDER_NUM', 'FIRE_NUM',
#        'ELE_SCH_NUM', 'MID_SCH_NUM', 'HIGH_SCH_NUM', 'CCTV_NUM', 'POLICE_NUM',
#        'BIKE_NUM', 'CAR_SHR_NUM', 'SUBWAY_NUM', 'SAFE_DLVR_NUM', 'DPTM_NUM',
#        'ANI_HSPT_NUM', 'PHARM_NUM', 'LEISURE_NUM', 'KIDS_NUM', 'SPORT_NUM',
#        'GYM_NUM', 'GOLF_NUM', 'STARBUCKS_NUM', 'MC_NUM', 'CON_NUM',
#        'NOISE_VIBRATION_NUM', 'CHILD_MED_NUM', 'CAFE_NUM', 'PARK_NUM',
#        'HOSPITAL_NUM', 'BUS_CNT', 'VEGAN_NUM', 'RETAIL_NUM', 'COLIVING_NUM',
#        'MZ_NUM'],
#       dtype='object')

# %%
density_df = pd.read_excel('../data/인구밀도.xlsx')
density_df
# Out:
#       GU  DONG    POP  AREA  DENSITY
# 0    종로구   사직동   9636  1.23     7834
# 1    종로구   삼청동   2739  1.49     1838
# 2    종로구   부암동   9782  2.27     4309
# 3    종로구   평창동  18329  8.87     2066
# 4    종로구   무악동   8297  0.36    23047
# ..   ...   ...    ...   ...      ...
# 421  강동구  천호2동  33753  1.57    21499
# 422  강동구    길동  45973  2.17    21186
# 423  강동구   강일동  32982  2.26    14594
# 424  강동구  상일1동  38929  2.65    14690
# 425  강동구  상일2동  10200  0.54    18889
#
# [426 rows x 5 columns]

# %% [markdown]
# ### 1.2 피처 별 가중치 부여 및 통합

# %% [markdown]
# ### 분류 가중치 비율
# - 교통 : 자전거 : 버스 : 지하철 = 0.06 : 0.93 : 1
# - 치안 : 안심택배 제외 나머지 합산
# - 건강 : 병원 : 약국 = 0.94 : 0.06
# - 편의 :
# - 교육 : 공교육(초,중,고) : 사교육(학원) = 1(0.9 : 0.07 : 0.03) : 0.7
# - 육아 : 합산

# %%
# 행정동 데이터, 밀도 데이터 병합
tmp_df = tmp_df.set_index(['GU','DONG'])
density_df = density_df.set_index(['GU','DONG'])
temp = tmp_df.join(density_df)
tmp = temp.reset_index()

# %%
# 컬럼 순서 정렬
tmp = tmp[['GU','DONG','DONG_CODE','POP','AREA','DENSITY',\
           'SUBWAY_NUM','BUS_CNT','BIKE_NUM',\
           'POLICE_NUM','FIRE_NUM','CCTV_NUM',\
           'HOSPITAL_NUM','PHARM_NUM',\
           'DPTM_NUM','RETAIL_NUM','CON_NUM','CAFE_NUM',\
           'ELE_SCH_NUM','MID_SCH_NUM','HIGH_SCH_NUM','ACADEMY_NUM',\
           'KINDER_NUM','CHILD_MED_NUM',\
           'MZ_NUM','COLIVING_NUM','KIDS_NUM','STARBUCKS_NUM','MC_NUM','NOISE_VIBRATION_NUM','SAFE_DLVR_NUM','LEISURE_NUM','SPORT_NUM','GYM_NUM','GOLF_NUM','CAR_SHR_NUM','ANI_HSPT_NUM','VEGAN_NUM']]
tmp
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  SUBWAY_NUM  BUS_CNT  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738    0.333333     14.0
# 1    종로구    사직동  1111053000   9636  1.23     7834    1.333333     16.0
# 2    종로구    삼청동  1111054000   2739  1.49     1838    1.000000     11.0
# 3    종로구    부암동  1111055000   9782  2.27     4309    0.000000      9.0
# 4    종로구    평창동  1111056000  18329  8.87     2066    0.000000     37.0
# ..   ...    ...         ...    ...   ...      ...         ...      ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979    0.333333     11.0
# 422  강동구   성내3동  1174066000  23346  0.71    32882    0.333333      9.0
# 423  강동구     길동  1174068500  45973  2.17    21186    1.000000     28.0
# 424  강동구   둔촌1동  1174069000    144  0.92      157    0.500000      4.0
# max    274.000000    10.000000  ...   480.250000  170.000000     101.000000
#
#              MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM      MC_NUM  \
# count    426.000000    426.000000  426.000000     426.000000  426.000000
# mean    6970.138498      0.178404    0.518779       1.302817    0.204225
# std     3195.571959      0.590994    0.656479       2.164240    0.363035
# min       33.000000      0.000000    0.000000       0.000000    0.000000
# 25%     4710.250000      0.000000    0.000000       0.333333    0.000000
# 50%     6607.000000      0.000000    0.333333       0.666667    0.000000
# 75%     8666.500000      0.000000    0.729167       1.333333    0.285714
# max    20429.000000      4.000000    4.250000      18.500000    4.000000
#
#        NOISE_VIBRATION_NUM  SAFE_DLVR_NUM  LEISURE_NUM   SPORT_NUM  \
# count           426.000000     426.000000   426.000000  426.000000
# mean           2452.551643       0.622066     1.194836    0.166667
# std            4534.820198       0.503566     1.606980    0.567719
# min             125.750000       0.000000     0.000000    0.000000
# 25%             442.037500       0.000000     0.000000    0.000000
# 50%            1014.000000       0.666667     0.833333    0.000000
# 75%            2163.500000       1.000000     1.750000    0.000000
# max           56112.000000       3.500000    15.000000    5.000000
#
#           GYM_NUM    GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM   VEGAN_NUM
# count  426.000000  426.000000   426.000000    426.000000  426.000000
# mean     7.448357    3.626761     4.133803      2.093897    3.929577
# std      7.034213    4.318573     3.156750      1.393441    4.372210
# min      0.000000    0.000000     0.000000      0.000000    0.000000
# 25%      3.500000    1.333333     2.285714      1.350000    1.500000
# 50%      6.000000    2.500000     3.500000      2.000000    3.000000
# 75%      9.000000    4.500000     5.000000      2.500000    4.666667
# max     60.000000   32.500000    24.000000     12.000000   40.000000
#
# [8 rows x 36 columns]

# %%
# 불필요 컬럼 제거
tmp = tmp.drop(['SPORT_NUM'],axis=1)

# %%
tmp.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'POP', 'AREA', 'DENSITY', 'SUBWAY_NUM',
#        'BUS_CNT', 'BIKE_NUM', 'POLICE_NUM', 'FIRE_NUM', 'CCTV_NUM',
#        'HOSPITAL_NUM', 'PHARM_NUM', 'DPTM_NUM', 'RETAIL_NUM', 'CON_NUM',
#        'CAFE_NUM', 'ELE_SCH_NUM', 'MID_SCH_NUM', 'HIGH_SCH_NUM', 'ACADEMY_NUM',
#        'KINDER_NUM', 'CHILD_MED_NUM', 'MZ_NUM', 'COLIVING_NUM', 'KIDS_NUM',
#        'STARBUCKS_NUM', 'MC_NUM', 'NOISE_VIBRATION_NUM', 'SAFE_DLVR_NUM',
#        'LEISURE_NUM', 'GYM_NUM', 'GOLF_NUM', 'CAR_SHR_NUM', 'ANI_HSPT_NUM',
#        'VEGAN_NUM'],
#       dtype='object')

# %%
# 피처 통합 함수
def assembling_features(df, weight, name): # 피처들로 구성된 데이터프레임, 피처별 가중치, 새로 생성할 피처의 이름
    columns = df.columns
    values = df[columns].values.tolist()
    sums = []
    
    for i in range(len(df)):
        sigma = 0
        for k in range(len(values[i])):
            sigma += values[i][k] * weight[k]
        sums.append(sigma)
    sum_df = pd.DataFrame(sums,columns=[name])
    return sum_df

# %%
# 합하고자 하는 column 끼리 묶어서 list로 생성
sum_list = [['SUBWAY_NUM','BUS_CNT','BIKE_NUM'],
            ['POLICE_NUM','FIRE_NUM','CCTV_NUM'],
            ['HOSPITAL_NUM','PHARM_NUM'],
            ['DPTM_NUM','RETAIL_NUM','CON_NUM','CAFE_NUM'],
            ['ELE_SCH_NUM','MID_SCH_NUM','HIGH_SCH_NUM','ACADEMY_NUM'],
            ['KINDER_NUM','CHILD_MED_NUM']]
# 각 묶어지는 컬럼 별 가중치 list
weight_list = [[1,0.93,0.06],[1,1,1],[0.94,0.06],[0.04,0.27,0.44,0.25],[0.9,0.07,0.03,0.7],[1,1]]

# 묶어진 column 들의 각각의 column명 list
name_list = ['TRANSPORT','SECURITY','HEALTH','CONVENIENCE','EDUCATION','PARENTING']

# %%
# 큰 카테고리로 묶는 함수
def assembling(df, sum_list, weight_list, name_list): 
    df_tmp = pd.DataFrame(data=range(len(df)))
    for j in range(len(sum_list)):
        tmp_df = df[sum_list[j]]
        name = name_list[j]
        w = weight_list[j]
        sum_df = assembling_features(tmp_df,w,name)

        tmp_df[name_list[j]] = sum_df.values
        tmp_df = tmp_df.drop(sum_list[j],axis=1)
        df_tmp = df_tmp.join(tmp_df)
    del(df_tmp[0])
    return df_tmp

# %%
# 컬럼 끼리 더한 데이터
asmb_df = assembling(tmp,sum_list,weight_list,name_list)
asmb_df
# Out:
#      TRANSPORT    SECURITY      HEALTH  CONVENIENCE  EDUCATION  PARENTING
# 0    13.693333   59.666667   11.226667    11.676667  14.630000   7.333333
# 1    16.913333   44.666667   71.226667    34.506667  15.100000  20.333333
# 2    11.650000   23.000000    6.700000    13.880000   1.500000  11.000000
# 3     8.670000   43.000000    3.820000    11.020000  20.500000   5.000000
# 4    34.830000   22.000000   13.460000    11.640000  19.630000  10.000000
# ..         ...         ...         ...          ...        ...        ...
# 421  10.923333   53.333333   56.533333    29.830000  45.556667  20.666667
# 422   9.063333   53.333333   56.533333    29.830000  45.556667  20.666667
# 423  27.580000  120.000000  114.900000    51.350000  75.470000  30.000000
# 424   4.550000   33.500000   14.230000    11.855000  28.535000   0.000000
# 425  19.430000   33.500000   14.230000    11.855000  28.535000   0.000000
#
# [426 rows x 6 columns]

# %%
# 병합하고 컬럼 순서 재정렬하는 함수
def data_frame_redirect(df, asmb_df, sum_list, name_list):
    for i in range(len(sum_list)):
        df = df.drop(sum_list[i],axis=1)
    df = df.join(asmb_df)
    column_list = ['GU','DONG','DONG_CODE','POP','AREA','DENSITY'] + name_list +['MZ_NUM','COLIVING_NUM','KIDS_NUM','STARBUCKS_NUM','MC_NUM','NOISE_VIBRATION_NUM','LEISURE_NUM','GYM_NUM','GOLF_NUM','CAR_SHR_NUM','ANI_HSPT_NUM','VEGAN_NUM']
    df = df[column_list]
    return df

# %%
tmp_df = data_frame_redirect(tmp, asmb_df, sum_list, name_list) # 묶고 묶을 때 사용한 컬럼 제거한 뒤 정리된 데이터 프레임
tmp_df.columns
# Out:
# Index(['GU', 'DONG', 'DONG_CODE', 'POP', 'AREA', 'DENSITY', 'TRANSPORT',
#        'SECURITY', 'HEALTH', 'CONVENIENCE', 'EDUCATION', 'PARENTING', 'MZ_NUM',
#        'COLIVING_NUM', 'KIDS_NUM', 'STARBUCKS_NUM', 'MC_NUM',
#        'NOISE_VIBRATION_NUM', 'LEISURE_NUM', 'GYM_NUM', 'GOLF_NUM',
#        'CAR_SHR_NUM', 'ANI_HSPT_NUM', 'VEGAN_NUM'],
#       dtype='object')

# %%
tmp_df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT    SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738  13.693333   59.666667
# 1    종로구    사직동  1111053000   9636  1.23     7834  16.913333   44.666667
# 2    종로구    삼청동  1111054000   2739  1.49     1838  11.650000   23.000000
# 3    종로구    부암동  1111055000   9782  2.27     4309   8.670000   43.000000
# 4    종로구    평창동  1111056000  18329  8.87     2066  34.830000   22.000000
# ..   ...    ...         ...    ...   ...      ...        ...         ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979  10.923333   53.333333
# 422  강동구   성내3동  1174066000  23346  0.71    32882   9.063333   53.333333
# 423  강동구     길동  1174068500  45973  2.17    21186  27.580000  120.000000
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.550000   33.500000
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.430000   33.500000
#
#          HEALTH  CONVENIENCE  EDUCATION  PARENTING  MZ_NUM  COLIVING_NUM  \
# 0     11.226667    11.676667  14.630000   7.333333    3210           0.0
# 1     71.226667    34.506667  15.100000  20.333333    2749           1.0
# 2      6.700000    13.880000   1.500000  11.000000     684           0.0
# 3      3.820000    11.020000  20.500000   5.000000    2585           0.0
# 4     13.460000    11.640000  19.630000  10.000000    4597           0.0
# ..          ...          ...        ...        ...     ...           ...
# 421   56.533333    29.830000  45.556667  20.666667    8130           0.0
# 422   56.533333    29.830000  45.556667  20.666667    7120           0.0
# 423  114.900000    51.350000  75.470000  30.000000   14486           0.0
# 424   14.230000    11.855000  28.535000   0.000000      33           0.0
# 425   14.230000    11.855000  28.535000   0.000000    7001           0.0
#
#      KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.333333     0.0         18816.000000     1.000000
# 1    0.000000       7.333333     0.0         22848.000000     1.000000
# 2    0.000000       1.000000     0.0         14112.000000     0.000000
# 3    0.000000       0.000000     0.0          6048.000000     0.000000
# 4    0.000000       1.000000     0.0          4032.000000     0.000000
# ..        ...            ...     ...                  ...          ...
# 421  0.666667       1.333333     0.0          1442.333333     1.666667
# 422  0.666667       1.333333     0.0          1442.333333     1.666667
# 423  1.000000       2.000000     0.0          4327.000000     3.000000
# 424  0.000000       0.000000     0.5          2163.500000     0.000000
# 425  0.000000       0.000000     0.5          2163.500000     0.000000
#
#      GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  VEGAN_NUM
# 0        0.0  0.000000     1.000000      2.000000   5.000000
# 50%        2.000000    3.000000
# 75%        2.500000    4.666667
# max       12.000000   40.000000

# %% [markdown]
# ### 1.3 면적 당 수치 계산

# %%
area = tmp_df['AREA']

# %%
columns = tmp_df.columns[6:]

# %%
for i in range(len(area)):
    for column in columns:
        tmp_df[column][i] = tmp_df[column][i] / area[i]
tmp_df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT   SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   5.328145  23.216602
# 1    종로구    사직동  1111053000   9636  1.23     7834  13.750678  36.314363
# 2    종로구    삼청동  1111054000   2739  1.49     1838   7.818792  15.436242
# 3    종로구    부암동  1111055000   9782  2.27     4309   3.819383  18.942731
# 4    종로구    평창동  1111056000  18329  8.87     2066   3.926719   2.480271
# ..   ...    ...         ...    ...   ...      ...        ...        ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979  16.303483  79.601990
# 422  강동구   성내3동  1174066000  23346  0.71    32882  12.765258  75.117371
# 423  강동구     길동  1174068500  45973  2.17    21186  12.709677  55.299539
# 424  강동구   둔촌1동  1174069000    144  0.92      157   4.945652  36.413043
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291  19.826531  34.183673
#
#         HEALTH  CONVENIENCE  EDUCATION  PARENTING        MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   5.692607   2.853437   1249.027237      0.000000
# 1    57.907859    28.054201  12.276423  16.531165   2234.959350      0.813008
# 2     4.496644     9.315436   1.006711   7.382550    459.060403      0.000000
# 3     1.682819     4.854626   9.030837   2.202643   1138.766520      0.000000
# 4     1.517475     1.312289   2.213078   1.127396    518.263811      0.000000
# ..         ...          ...        ...        ...           ...           ...
# 421  84.378109    44.522388  67.995025  30.845771  12134.328358      0.000000
# 422  79.624413    42.014085  64.164319  29.107981  10028.169014      0.000000
# 423  52.949309    23.663594  34.778802  13.824885   6675.576037      0.000000
# 424  15.467391    12.885870  31.016304   0.000000     35.869565      0.000000
# 425  14.520408    12.096939  29.117347   0.000000   7143.877551      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.129702  0.000000          7321.400778     0.389105
# 1    0.000000       5.962060  0.000000         18575.609756     0.813008
# 2    0.000000       0.671141  0.000000          9471.140940     0.000000
# 3    0.000000       0.000000  0.000000          2664.317181     0.000000
# 4    0.000000       0.112740  0.000000           454.565953     0.000000
# ..        ...            ...       ...                  ...          ...
# 421  0.995025       1.990050  0.000000          2152.736318     2.487562
# 422  0.938967       1.877934  0.000000          2031.455399     2.347418
# 423  0.460829       0.921659  0.000000          1994.009217     1.382488
# 424  0.000000       0.000000  0.543478          2351.630435     0.000000
# 425  0.000000       0.000000  0.510204          2207.653061     0.000000
#
#        GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  VEGAN_NUM
# 0     0.000000  0.000000     0.389105      0.778210   1.945525
# 1    14.634146  2.439024     4.065041      0.813008   6.504065
# 2     2.013423  0.000000     0.671141      0.000000   4.026846
# %% [markdown]
# ### 1.4 왜도/첨도 측정 : 일부 특성들을 범주화

# %% [markdown]
# #### 1.4.1 왜도/첨도 측정

# %%
columns = tmp_df.columns[6:]
skews = []
kurtosises = []
for column in columns:
    # 왜도 : 절댓값 3을 넘지 않아야 함
    skews.append(skew(tmp_df[column]))

    # 첨도 : 절댓값 8~10을 넘지 않아야 함
    kurtosises.append(kurtosis(tmp_df[column], fisher=True))
res = [skews,kurtosises]
standard_df = pd.DataFrame(data=res, index=['왜도','첨도'],columns=columns)

# %%
standard_df
# Out:
#     TRANSPORT   SECURITY    HEALTH  CONVENIENCE  EDUCATION  PARENTING  \
# 왜도   5.072204   3.132583  1.547339     2.001621    4.00260   1.361778
# 첨도  56.811500  19.030154  4.134766     7.570355   23.55307   2.534743
#
#       MZ_NUM  COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM     MC_NUM  \
# 왜도  0.685738      4.792325  1.895467       4.566057   3.144228
# 첨도  1.285944     28.221618  4.395937      32.014755  18.791080
#
#     NOISE_VIBRATION_NUM  LEISURE_NUM   GYM_NUM   GOLF_NUM  CAR_SHR_NUM  \
# 왜도             3.912226     2.655983  1.742896   2.604953     1.049841
# 첨도            19.032090     9.877211  4.295465  10.645659     1.592107
#
#     ANI_HSPT_NUM  VEGAN_NUM
# 왜도      1.033603   3.429052
# 첨도      1.487151  21.454968

# %%
over = []
for column in standard_df.columns:
    if((standard_df[column][0] > 3)):
        over.append([column, standard_df[column][0], standard_df[column][1]])
over_std = pd.DataFrame(over).T

# %%
over_std.columns = over_std.iloc[0]
over_std = over_std.iloc[1:]
over_std
# Out:
# 0 TRANSPORT   SECURITY EDUCATION COLIVING_NUM STARBUCKS_NUM    MC_NUM  \
# 1  5.072204   3.132583    4.0026     4.792325      4.566057  3.144228
# 2   56.8115  19.030154  23.55307    28.221618     32.014755  18.79108
#
# 0 NOISE_VIBRATION_NUM  VEGAN_NUM
# 1            3.912226   3.429052
# 2            19.03209  21.454968

# %%
over = []
for column in standard_df.columns:
    if((standard_df[column][1] > 8)):
        over.append([column, standard_df[column][0], standard_df[column][1]])
over_std = pd.DataFrame(over).T

# %%
over_std.columns = over_std.iloc[0]
over_std = over_std.iloc[1:]
over_std
# Out:
# 0 TRANSPORT   SECURITY EDUCATION COLIVING_NUM STARBUCKS_NUM    MC_NUM  \
# 1  5.072204   3.132583    4.0026     4.792325      4.566057  3.144228
# 2   56.8115  19.030154  23.55307    28.221618     32.014755  18.79108
#
# 0 NOISE_VIBRATION_NUM LEISURE_NUM   GOLF_NUM  VEGAN_NUM
# 1            3.912226    2.655983   2.604953   3.429052
# 2            19.03209    9.877211  10.645659  21.454968

# %%
over = []
for column in standard_df.columns:
    if((standard_df[column][0] > 3) and (standard_df[column][1] > 8)):
        over.append([column, standard_df[column][0], standard_df[column][1]])
over_std = pd.DataFrame(over).T

# %%
over_std.columns = over_std.iloc[0]
over_std = over_std.iloc[1:]
over_std
# Out:
# 0 TRANSPORT   SECURITY EDUCATION COLIVING_NUM STARBUCKS_NUM    MC_NUM  \
# 1  5.072204   3.132583    4.0026     4.792325      4.566057  3.144228
# 2   56.8115  19.030154  23.55307    28.221618     32.014755  18.79108
#
# 0 NOISE_VIBRATION_NUM  VEGAN_NUM
# 1            3.912226   3.429052
# 2            19.03209  21.454968

# %%
over_std.columns
# Out:
# Index(['TRANSPORT', 'SECURITY', 'EDUCATION', 'COLIVING_NUM', 'STARBUCKS_NUM',
#        'MC_NUM', 'NOISE_VIBRATION_NUM', 'VEGAN_NUM'],
#       dtype='object', name=0)

# %%
tmp_df.hist(figsize = (20, 20), bins = 22, legend = False)
# Out:
# array([[<AxesSubplot:title={'center':'DONG_CODE'}>,
#         <AxesSubplot:title={'center':'POP'}>,
#         <AxesSubplot:title={'center':'AREA'}>,
#         <AxesSubplot:title={'center':'DENSITY'}>,
#         <AxesSubplot:title={'center':'TRANSPORT'}>],
#        [<AxesSubplot:title={'center':'SECURITY'}>,
#         <AxesSubplot:title={'center':'HEALTH'}>,
#         <AxesSubplot:title={'center':'CONVENIENCE'}>,
#         <AxesSubplot:title={'center':'EDUCATION'}>,
#         <AxesSubplot:title={'center':'PARENTING'}>],
#        [<AxesSubplot:title={'center':'MZ_NUM'}>,
#         <AxesSubplot:title={'center':'COLIVING_NUM'}>,
#         <AxesSubplot:title={'center':'KIDS_NUM'}>,
#         <AxesSubplot:title={'center':'STARBUCKS_NUM'}>,
#         <AxesSubplot:title={'center':'MC_NUM'}>],
#        [<AxesSubplot:title={'center':'NOISE_VIBRATION_NUM'}>,
#         <AxesSubplot:title={'center':'LEISURE_NUM'}>,
#         <AxesSubplot:title={'center':'GYM_NUM'}>,
#         <AxesSubplot:title={'center':'GOLF_NUM'}>,
#         <AxesSubplot:title={'center':'CAR_SHR_NUM'}>],
#        [<AxesSubplot:title={'center':'ANI_HSPT_NUM'}>,
#         <AxesSubplot:title={'center':'VEGAN_NUM'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
origin_df = tmp_df.copy()

# %% [markdown]
# #### 1.4.2 최댓값 제한
# - 교통
# - 보안
# - 교육
# - 코리빙
# - 스타벅스
# - 맥도날드
# - 소음

# %% [markdown]
# **교통**

# %%
tmp_df['TRANSPORT'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['TRANSPORT'].describe()
# Out:
# count    426.000000
# mean      14.899219
# std        9.722790
# min        1.402529
# 25%        9.331860
# 50%       13.183811
# 75%       18.691749
# max      136.688552
# Name: TRANSPORT, dtype: float64

# %%
t = tmp_df['TRANSPORT'].quantile(0.95)
t
# Out:
# 29.322401908801698

# %%
tmp_df['TRANSPORT'] = np.where(tmp_df['TRANSPORT'] > t, t, tmp_df['TRANSPORT'])

# %%
tmp_df['TRANSPORT'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['TRANSPORT']
# Out:
# 0       5.328145
# 1      13.750678
# 2       7.818792
# 3       3.819383
# 4       3.926719
#          ...
# 421    16.303483
# 422    12.765258
# 423    12.709677
# 424     4.945652
# 425    19.826531
# Name: TRANSPORT, Length: 426, dtype: float64

# %%
tmp_df['TRANSPORT'] = np.log1p(tmp_df['TRANSPORT'])

# %%
tmp_df['TRANSPORT'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **치안**

# %%
tmp_df['SECURITY'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['SECURITY'].describe()
# Out:
# count    426.000000
# mean      56.413573
# std       50.615331
# min        1.104101
# 25%       23.515357
# 50%       43.993671
# 75%       73.260354
# max      522.500000
# Name: SECURITY, dtype: float64

# %%
s = tmp_df['SECURITY'].quantile(0.95)
s
# Out:
# 143.22741982936157

# %%
tmp_df['SECURITY'] = np.where(tmp_df['SECURITY'] > s, s, tmp_df['SECURITY'])

# %%
tmp_df['SECURITY'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['SECURITY'] = np.log1p(tmp_df['SECURITY'])

# %%
tmp_df['SECURITY'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **교육**

# %%
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %%
e = tmp_df['EDUCATION'].quantile(0.95)
e
# Out:
# 105.6954219807904

# %%
tmp_df['EDUCATION'] = np.where(tmp_df['EDUCATION'] > e, e, tmp_df['EDUCATION'])

# %%
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['EDUCATION'] = np.log1p(tmp_df['EDUCATION'])

# %%
tmp_df['EDUCATION'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **코리빙**

# %%
tmp_df['COLIVING_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
c = tmp_df['COLIVING_NUM'].quantile(0.95)
c
# Out:
# 1.276595744680851

# %%
tmp_df['COLIVING_NUM'] = np.where(tmp_df['COLIVING_NUM'] > c, c, tmp_df['COLIVING_NUM'])

# %%
tmp_df['COLIVING_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['COLIVING_NUM'] = np.log1p(tmp_df['COLIVING_NUM'])

# %%
tmp_df['COLIVING_NUM'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **스타벅스**

# %%
tmp_df['STARBUCKS_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
star = tmp_df['STARBUCKS_NUM'].quantile(0.95)
star
# Out:
# 3.9453748006379583

# %%
tmp_df['STARBUCKS_NUM'] = np.where(tmp_df['STARBUCKS_NUM'] > star, star, tmp_df['STARBUCKS_NUM'])

# %%
tmp_df['STARBUCKS_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['STARBUCKS_NUM'] = np.log1p(tmp_df['STARBUCKS_NUM'])

# %%
tmp_df['STARBUCKS_NUM'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **맥도날드**

# %%
tmp_df['MC_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
mc = tmp_df['MC_NUM'].quantile(0.95)
print(mc)
tmp_df['MC_NUM'] = np.where(tmp_df['MC_NUM'] > mc, mc, tmp_df['MC_NUM'])
print(tmp_df['MC_NUM'].hist())
# Out:
# 0.7782451923076923
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
tmp_df['MC_NUM'] = np.log1p(tmp_df['MC_NUM'])
print(tmp_df['MC_NUM'].hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# **소음**

# %%
tmp_df['NOISE_VIBRATION_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
nv = tmp_df['NOISE_VIBRATION_NUM'].quantile(0.95)
print(mc)
tmp_df['NOISE_VIBRATION_NUM'] = np.where(tmp_df['NOISE_VIBRATION_NUM'] > nv, nv, tmp_df['NOISE_VIBRATION_NUM'])
print(tmp_df['NOISE_VIBRATION_NUM'].hist())
# Out:
# 0.7782451923076923
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
tmp_df['NOISE_VIBRATION_NUM'] = np.log1p(tmp_df['NOISE_VIBRATION_NUM'])
print(tmp_df['NOISE_VIBRATION_NUM'].hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# **비건**

# %%
tmp_df['VEGAN_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
v = tmp_df['VEGAN_NUM'].quantile(0.95)
v
# Out:
# 9.544721998388397

# %%
tmp_df['VEGAN_NUM'] = np.where(tmp_df['VEGAN_NUM'] > v, v, tmp_df['VEGAN_NUM'])

# %%
tmp_df['VEGAN_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
tmp_df['VEGAN_NUM'] = np.log1p(tmp_df['VEGAN_NUM'])

# %%
tmp_df['VEGAN_NUM'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **건강**

# %%
tmp_df['HEALTH'].hist()
# Out:
# <AxesSubplot:>

# %%
h = tmp_df['HEALTH'].quantile(0.95)
print(h)
tmp_df['HEALTH'] = np.where(tmp_df['HEALTH'] > h, h, tmp_df['HEALTH'])
tmp_df['HEALTH'].hist()
# Out:
# 96.691258111031
# <AxesSubplot:>

# %% [markdown]
# **편의시설**

# %%
tmp_df['CONVENIENCE'].hist()
# Out:
# <AxesSubplot:>

# %%
cv = tmp_df['CONVENIENCE'].quantile(0.95)
print(cv)
tmp_df['CONVENIENCE'] = np.where(tmp_df['CONVENIENCE'] > cv, cv, tmp_df['CONVENIENCE'])
tmp_df['CONVENIENCE'].hist()
# Out:
# 49.46700044121973
# <AxesSubplot:>

# %% [markdown]
# **레저**

# %%
tmp_df['LEISURE_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
l = tmp_df['LEISURE_NUM'].quantile(0.95)
print(l)
tmp_df['LEISURE_NUM'] = np.where(tmp_df['LEISURE_NUM'] > l, l, tmp_df['LEISURE_NUM'])
tmp_df['LEISURE_NUM'].hist()
# Out:
# 4.2669172932330826
# <AxesSubplot:>

# %% [markdown]
# **골프**

# %%
tmp_df['GOLF_NUM'].hist()
# Out:
# <AxesSubplot:>

# %%
g = tmp_df['GOLF_NUM'].quantile(0.95)
print(g)
tmp_df['GOLF_NUM'] = np.where(tmp_df['GOLF_NUM'] > g, g, tmp_df['GOLF_NUM'])
tmp_df['GOLF_NUM'].hist()
# Out:
# 9.501347708894876
# <AxesSubplot:>

# %% [markdown]
# **RobustScaling**

# %%
df = tmp_df.copy()
df
# Out:
#       GU   DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# 0    종로구  청운효자동  1111051500  12177  2.57     4738   1.845007  3.187038
# 1    종로구    사직동  1111053000   9636  1.23     7834   2.691289  3.619378
# 2    종로구    삼청동  1111054000   2739  1.49     1838   2.176885  2.799489
# 3    종로구    부암동  1111055000   9782  2.27     4309   1.572646  2.992865
# 4    종로구    평창동  1111056000  18329  8.87     2066   1.594673  1.247110
# ..   ...    ...         ...    ...   ...      ...        ...       ...
# 421  강동구   성내2동  1174065000  24106  0.67    35979   2.850908  4.389523
# 422  강동구   성내3동  1174066000  23346  0.71    32882   2.622148  4.332277
# 423  강동구     길동  1174068500  45973  2.17    21186   2.618102  4.030686
# 424  강동구   둔촌1동  1174069000    144  0.92      157   1.782660  3.622019
# 425  강동구   둔촌2동  1174070000  24785  0.98    25291   3.036228  3.560582
#
#         HEALTH  CONVENIENCE  EDUCATION  PARENTING        MZ_NUM  COLIVING_NUM  \
# 0     4.368353     4.543450   1.901003   2.853437   1249.027237      0.000000
# 1    57.907859    28.054201   2.585990  16.531165   2234.959350      0.594987
# 2     4.496644     9.315436   0.696497   7.382550    459.060403      0.000000
# 3     1.682819     4.854626   2.305664   2.202643   1138.766520      0.000000
# 4     1.517475     1.312289   1.167229   1.127396    518.263811      0.000000
# ..         ...          ...        ...        ...           ...           ...
# 421  84.378109    44.522388   4.234034  30.845771  12134.328358      0.000000
# 422  79.624413    42.014085   4.176912  29.107981  10028.169014      0.000000
# 423  52.949309    23.663594   3.577356  13.824885   6675.576037      0.000000
# 424  15.467391    12.885870   3.466245   0.000000     35.869565      0.000000
# 425  14.520408    12.096939   3.405101   0.000000   7143.877551      0.000000
#
#      KIDS_NUM  STARBUCKS_NUM    MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# 0    0.000000       0.121954  0.000000             8.898694     0.389105
# 1    0.000000       1.598453  0.000000             9.227525     0.813008
# 2    0.000000       0.513507  0.000000             9.156110     0.000000
# 3    0.000000       0.000000  0.000000             7.888078     0.000000
# 4    0.000000       0.106825  0.000000             6.121540     0.000000
# ..        ...            ...       ...                  ...          ...
# 421  0.995025       1.095290  0.000000             7.674959     2.487562
# 422  0.938967       1.057073  0.000000             7.617000     2.347418
# 423  0.460829       0.653189  0.000000             7.598404     1.382488
# 424  0.000000       0.000000  0.434038             7.763289     0.000000
# 425  0.000000       0.000000  0.412245             7.700138     0.000000
#
#        GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  VEGAN_NUM
# 0     0.000000  0.000000     0.389105      0.778210   1.080287
# 1    14.634146  2.439024     4.065041      0.813008   2.015445
# 2     2.013423  0.000000     0.671141      0.000000   1.614793
# 3     0.881057  0.881057     2.202643      1.321586   0.365010
# 4     0.563698  0.563698     0.000000      0.000000   0.203332
# ..         ...       ...          ...           ...        ...
# 421  14.925373  6.965174     9.950249      3.980100   1.500200
# 422  14.084507  6.572770     9.389671      3.755869   1.455444
# 423   8.294931  4.147465     4.608295      3.686636   0.379004
# 424   4.347826  3.260870     2.173913      1.630435   0.434038
# 425   4.081633  3.061224     2.040816      1.530612   0.412245
#
# [426 rows x 24 columns]

# %%
col = df.columns[6:]
data = df[col]

# %%
scaler = RobustScaler()
scaler.fit(data)
df_scaled = scaler.transform(data)
df_scaled
# Out:
# array([[-1.25137342, -0.55893333, -0.94200149, ..., -0.87891199,
#         -0.58314657, -0.31029508],
#        [ 0.06075936, -0.16885156,  0.687746  , ...,  0.13632856,
#         -0.56506546,  0.78829456],
#        [-0.7368077 , -0.90860279, -0.93809629, ..., -0.80101773,
#         -0.98750582,  0.31762277],
#        ...,
#        [-0.05271481,  0.20225405,  0.53680728, ...,  0.28636758,
#          0.92807625, -1.13413682],
#        [-1.34804038, -0.16646863, -0.60414574, ..., -0.38597369,
#         -0.14032924, -1.06948479],
#        [ 0.59557568, -0.22190083, -0.63297199, ..., -0.42273309,
#         -0.19219719, -1.09508723]])

# %%
df[col] = df_scaled
data = df[col]

# %%
data
# Out:
#      TRANSPORT  SECURITY    HEALTH  CONVENIENCE  EDUCATION  PARENTING  \
# 0    -1.251373 -0.558933 -0.942001    -0.944897  -1.689682  -0.803218
# 1     0.060759 -0.168852  0.687746     0.548133  -0.968695  -0.415289
# 2    -0.736808 -0.908603 -0.938096    -0.641856  -2.957494  -0.674763
# 3    -1.673661 -0.734128 -1.023749    -0.925136  -1.263754  -0.821676
# 4    -1.639508 -2.309248 -1.028782    -1.150089  -2.462022  -0.852172
# ..         ...       ...       ...          ...        ...        ...
# 421   0.308243  0.526017  1.493503     1.593932   0.765966  -0.009298
# 422  -0.046442  0.474366  1.348800     1.434644   0.705841  -0.058585
# 423  -0.052715  0.202254  0.536807     0.269312   0.074774  -0.492045
# 424  -1.348040 -0.166469 -0.604146    -0.415119  -0.042176  -0.884147
# 425   0.595576 -0.221901 -0.632972    -0.465219  -0.106534  -0.884147
#
#        MZ_NUM  COLIVING_NUM  KIDS_NUM  STARBUCKS_NUM    MC_NUM  \
# 0   -1.093461      0.000000 -0.439314      -0.565210  0.000000
# 1   -0.907741      0.594987 -0.439314       1.642479  0.000000
# 2   -1.242268      0.000000 -0.439314       0.020247  0.000000
# 3   -1.114231      0.000000 -0.439314      -0.747557  0.000000
# 4   -1.231116      0.000000 -0.439314      -0.587830  0.000000
# ..        ...           ...       ...            ...       ...
# 421  0.957008      0.000000  0.895012       0.890140  0.000000
# 422  0.560270      0.000000  0.819839       0.832997  0.000000
# 423 -0.071260      0.000000  0.178657       0.229103  0.000000
# 424 -1.321984      0.000000 -0.439314      -0.747557  1.578649
# 425  0.016954      0.000000 -0.439314      -0.747557  1.499383
#
#      NOISE_VIBRATION_NUM  LEISURE_NUM   GYM_NUM  GOLF_NUM  CAR_SHR_NUM  \
# 0               1.296060    -0.203745 -0.906523 -0.792079    -0.878912
# 1               1.504113     0.049270  1.341133 -0.001489     0.136329
# 2               1.458929    -0.435990 -0.597282 -0.792079    -0.801018
# 3               0.656637    -0.435990 -0.771202 -0.506491    -0.378039
# 4              -0.461063    -0.435990 -0.819945 -0.609361    -0.986377
# ..                   ...          ...       ...       ...          ...
# 421             0.521795     1.048760  1.385863  1.465626     1.761738
# 422             0.485124     0.965113  1.256714  1.338431     1.606915
# 423             0.473358     0.389176  0.367494  0.552288     0.286368
# 424             0.577682    -0.435990 -0.238741  0.264906    -0.385974
# 425             0.537726    -0.435990 -0.279626  0.200192    -0.422733
#
#      ANI_HSPT_NUM  VEGAN_NUM
# 0       -0.583147  -0.310295
# 1       -0.565065   0.788295
# 2       -0.987506   0.317623
# 3       -0.300808  -1.150577
# 4       -0.987506  -1.340511
# ..            ...        ...
# 421      1.080560   0.183004
# 422      0.964050   0.130425
# 423      0.928076  -1.134137
# 424     -0.140329  -1.069485
# 425     -0.192197  -1.095087
#
# [426 rows x 18 columns]

# %% [markdown]
# ## 2. K-means 군집화

# %% [markdown]
# ### 2.1 1차 k-means clustering

# %% [markdown]
# #### 2.1.1 Elbow 관측

# %%
# 차원 축소 및 변환
pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(data)

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# #### 2.1.2 k-means, n_cluster = 3

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
kmeans.fit(pca_transformed)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
kmeans.labels_
df = tmp_df.copy()
df['km_cluster'] = kmeans.labels_
df.groupby('km_cluster').count()
# Out:
#              GU  DONG  DONG_CODE  POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# km_cluster
# 0           225   225        225  225   225      225        225       225
# 1            84    84         84   84    84       84         84        84
# 2           117   117        117  117   117      117        117       117
#
#             HEALTH  CONVENIENCE  EDUCATION  PARENTING  MZ_NUM  COLIVING_NUM  \
# km_cluster
# 0              225          225        225        225     225           225
# 1               84           84         84         84      84            84
# 2              117          117        117        117     117           117
#
#             KIDS_NUM  STARBUCKS_NUM  MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM  \
# km_cluster
# 0                225            225     225                  225          225
# 1                 84             84      84                   84           84
# 2                117            117     117                  117          117
#
#             GYM_NUM  GOLF_NUM  CAR_SHR_NUM  ANI_HSPT_NUM  VEGAN_NUM
# km_cluster
# 0               225       225          225           225        225
# 1                84        84           84            84         84
# 2               117       117          117           117        117

# %%
df['pca_x'] = pca_transformed[:,0]
df['pca_y'] = pca_transformed[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df[df['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>','<']
for i in range(marker_n):
    plt.scatter(x = df.loc[markers[i], 'pca_x'], y = df.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('2 Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2'])
plt.show()

# %%
df[df['pca_y'] > 8] # MZ 세대가 적고, 코리빙, 스타벅스가 많음
# Out:
# Empty DataFrame
# Columns: [GU, DONG, DONG_CODE, POP, AREA, DENSITY, TRANSPORT, SECURITY, HEALTH, CONVENIENCE, EDUCATION, PARENTING, MZ_NUM, COLIVING_NUM, KIDS_NUM, STARBUCKS_NUM, MC_NUM, NOISE_VIBRATION_NUM, LEISURE_NUM, GYM_NUM, GOLF_NUM, CAR_SHR_NUM, ANI_HSPT_NUM, VEGAN_NUM, km_cluster, pca_x, pca_y]
# Index: []

# %%
df[df['pca_x'] > 6] # 편의 시설이 많고, 스타벅스가 많음
# Out:
#       GU  DONG   DONG_CODE    POP  AREA  DENSITY  TRANSPORT  SECURITY  \
# 224  양천구   목3동  1147053000  21977  0.53    41466   2.941455  4.227522
# std       1.459179   6.364987   2.663802     2.783281      1.597023
# min       0.000000   5.907173   0.967742     1.287554      0.000000
# 25%       0.971251  11.111111   4.027383     5.555556      2.967540
# 50%       1.859834  14.052389   6.414286     7.121851      4.016129
# 75%       3.547059  18.997760   9.120813     8.962264      4.871324
# max       4.266917  39.130435   9.501348    16.956522      9.090909
#
#        VEGAN_NUM  km_cluster      pca_x      pca_y
# count  84.000000        84.0  84.000000  84.000000
# mean    1.817391         1.0   3.216739   0.461224
# std     0.384060         0.0   1.217663   0.956385
# min     0.810930         1.0   1.323222  -1.651704
# 25%     1.515480         1.0   2.291171  -0.141658
# 50%     1.818980         1.0   3.059546   0.422598
# 75%     2.146435         1.0   3.871402   1.088694
# max     2.355625         1.0   6.940873   3.080343

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed)      
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 426 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
score = silhouette_score(data,df['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
# Out:
# Silhouette Score :  0.190

# %% [markdown]
# #### 2.1.3 각 군집 별 데이터 확인

# %% [markdown]
# **km_cluster == 0**

# %%
df_cluster_0 = df[df['km_cluster'] == 0][col]

# %%
df_cluster_0.describe()
# Out:
#         TRANSPORT    SECURITY      HEALTH  CONVENIENCE   EDUCATION  \
# count  225.000000  225.000000  225.000000   225.000000  225.000000
# mean     2.767758    3.928499   38.926022    21.759121    3.533910
# std      0.383521    0.590248   14.019435     7.831681    0.586530
# min      1.825294    2.055744   11.052632     6.979381    0.773190
# 25%      2.500665    3.603166   28.440476    16.609589    3.297813
# 50%      2.767580    3.922445   38.206186    20.641176    3.607569
# 75%      3.048079    4.307671   47.473118    26.444444    3.873752
# max      3.411887    4.971391   96.691258    49.467000    4.669978
#
#         PARENTING        MZ_NUM  COLIVING_NUM    KIDS_NUM  STARBUCKS_NUM  \
# count  225.000000    225.000000    225.000000  225.000000     225.000000
# mean    40.485409   7827.594151      0.096611    0.438807       0.584529
# std     23.891520   3084.217552      0.251522    0.483364       0.425010
# min      1.111111    402.970297      0.000000    0.000000       0.000000
# 25%     25.490196   6009.195402      0.000000    0.000000       0.344669
# 50%     36.363636   7902.898551      0.000000    0.371287       0.512610
# 75%     51.067073   9392.941176      0.000000    0.645161       0.777705
# max    143.137255  19100.000000      0.822681    2.857143       1.598453
#
#            MC_NUM  NOISE_VIBRATION_NUM  LEISURE_NUM     GYM_NUM    GOLF_NUM  \
# count  225.000000           225.000000   225.000000  225.000000  225.000000
# mean     0.144348             7.026924     1.135090    6.377526    2.908910
# std      0.190484             1.137074     1.125605    2.846978    1.917880
# min      0.000000             4.738724     0.000000    0.000000    0.000000
# 25%      0.000000             6.163270     0.000000    4.216867    1.646091
# 50%      0.000000             6.879557     0.877193    6.214689    2.614379
# 75%      0.272205             7.681903     1.689189    8.387097    4.032258
# max      0.575627             9.227525     4.266917   14.634146    9.501348
#
#        CAR_SHR_NUM  ANI_HSPT_NUM   VEGAN_NUM
# count   225.000000    225.000000  225.000000
# mean      4.055832      2.105914    1.413612
# std       2.009031      1.099836    0.513060
# min       0.000000      0.000000    0.000000
# 25%       2.872928      1.372549    1.085454
# 50%       3.747073      2.089552    1.382171
# 75%       5.263158      2.750000    1.753732
# max      10.714286      5.357143    2.355625

# %%
df[df['km_cluster'] == 0]['DONG'].values
# Out:
# array(['사직동', '교남동', '가회동', '종로1.2.3.4가동', '종로5.6가동', '이화동', '혜화동',
#        '창신1동', '창신2동', '창신3동', '숭인2동', '소공동', '회현동', '필동', '광희동', '을지로동',
#        '신당동', '다산동', '약수동', '청구동', '신당5동', '중림동', '남영동', '청파동', '원효로1동',
#        '효창동', '용문동', '이태원1동', '왕십리2동', '마장동', '사근동', '행당1동', '금호1가동',
#        '금호2.3가동', '금호4가동', '성수1가2동', '성수2가1동', '성수2가3동', '중곡1동', '중곡3동',
#        '자양3동', '자양4동', '구의2동', '구의3동', '용신동', '제기동', '전농1동', '전농2동',
#        '답십리1동', '답십리2동', '회기동', '휘경1동', '휘경2동', '이문1동', '이문2동', '면목2동',
#        '면목4동', '면목5동', '면목본동', '상봉1동', '중화1동', '중화2동', '묵1동', '묵2동',
#        '망우3동', '신내2동', '삼선동', '안암동', '보문동', '길음1동', '종암동', '월곡1동', '월곡2동',
#        '장위1동', '장위2동', '장위3동', '삼양동', '미아동', '송중동', '송천동', '번1동', '번2동',
#        '수유2동', '수유3동', '창1동', '창2동', '창3동', '창4동', '창5동', '도봉2동', '쌍문2동',
#        '쌍문3동', '쌍문4동', '방학1동', '방학2동', '월계1동', '월계3동', '공릉1동', '하계2동',
#        '중계2.3동', '상계5동', '상계6.7동', '상계9동', '상계10동', '녹번동', '불광2동', '갈현1동',
#        '갈현2동', '구산동', '응암1동', '역촌동', '신사1동', '신사2동', '증산동', '천연동', '북아현동',
#        '충현동', '신촌동', '홍제3동', '남가좌2동', '북가좌1동', '북가좌2동', '도화동', '대흥동',
#        '신수동', '서강동', '망원1동', '망원2동', '연남동', '성산1동', '목1동', '목5동', '신월1동',
#        '신월2동', '신월4동', '신월5동', '신월6동', '신정4동', '신정6동', '신정7동', '화곡1동',
#        '화곡4동', '화곡본동', '화곡6동', '가양3동', '발산1동', '신도림동', '구로1동', '구로2동',
#        '구로3동', '구로5동', '가리봉동', '고척1동', '고척2동', '개봉1동', '개봉2동', '개봉3동',
#        '오류1동', '가산동', '독산3동', '시흥4동', '영등포본동', '당산2동', '문래동', '양평1동',
#        '신길1동', '신길3동', '신길4동', '신길6동', '신길7동', '대림1동', '대림2동', '노량진1동',
#        '노량진2동', '상도1동', '상도2동', '상도4동', '흑석동', '사당1동', '사당3동', '사당5동',
#        '대방동', '신대방1동', '신대방2동', '보라매동', '성현동', '행운동', '청룡동', '은천동', '인헌동',
#        '서원동', '신원동', '서림동', '신사동', '난향동', '조원동', '난곡동', '서초3동', '잠원동',
#        '반포본동', '반포1동', '반포2동', '반포3동', '반포4동', '방배4동', '압구정동', '삼성1동',
#        '대치2동', '도곡1동', '도곡2동', '일원1동', '거여1동', '거여2동', '마천1동', '오금동',
#        '가락본동', '가락1동', '가락2동', '장지동', '잠실본동', '상일2동', '명일2동', '암사1동',
#        '천호2동', '길동'], dtype=object)

# %% [markdown]
# **km_cluster == 1**

# %%
df_cluster_1 = df[df['km_cluster'] == 1][col]

# %%
df_cluster_1.describe()

# %%
df[df['km_cluster'] == 1]['DONG'].values

# %% [markdown]
# **km_cluster == 2**

# %%
df_cluster_2 = df[df['km_cluster'] == 2][col]

# %%
df_cluster_2.describe()

# %%
df[df['km_cluster'] == 2]['DONG'].values

# %% [markdown]
# ### 2.2 2차 k-means_clustering

# %% [markdown]
# #### 2.2.1 km_cluster == 0

# %% [markdown]
# - Elbow 관측

# %%
df_0 = df[df['km_cluster'] == 0][tmp_df.columns]
df_0

# %%
col_0 = df_0.columns[6:]
data_0 = df_0[col_0].values

# %%
pca_transformed_0 = pca.fit_transform(data_0)
df_0['pca_x'] = pca_transformed_0[:,0]
df_0['pca_y'] = pca_transformed_0[:,1]
df_0

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_0)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 3(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=0)
# label
label_0 = kmeans.fit(pca_transformed_0)
# Getting unique labels
u_labels = np.unique(label_0)

# %%
df_0['km_cluster'] = kmeans.labels_
df_0.groupby('km_cluster').count()

# %%
df_0['pca_x'] = pca_transformed_0[:,0]
df_0['pca_y'] = pca_transformed_0[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_0['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_0[df_0['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_0.loc[markers[i], 'pca_x'], y = df_0.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2'])
plt.show()

# %%
df_0[df_0['pca_y'] > 12.5] # 교육, MZ 세대가 많은 편, 동물병원 수가 많음

# %%
df_0[df_0['km_cluster'] == 2].describe()

# %%
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
visualizer.fit(pca_transformed_0)      
visualizer.show()

# %%
score = silhouette_score(data_0,df_0['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))

# %% [markdown]
# #### 2.2.2 km_cluster == 1

# %% [markdown]
# - Elbow 관측

# %%
df_1 = df[df['km_cluster'] == 1][tmp_df.columns]
df_1

# %%
col_1 = df_1.columns[6:]
data_1 = df_1[col_1].values

# %%
pca_transformed_1 = pca.fit_transform(data_1)
df_1['pca_x'] = pca_transformed_1[:,0]
df_1['pca_y'] = pca_transformed_1[:,1]
df_1

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_1)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 2(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, random_state=0)
# label
label_1 = kmeans.fit(pca_transformed_1)
# Getting unique labels
u_labels = np.unique(label_1)

# %%
df_1['km_cluster'] = kmeans.labels_
df_1.groupby('km_cluster').count()

# %%
df_1['pca_x'] = pca_transformed_1[:,0]
df_1['pca_y'] = pca_transformed_1[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_1['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_1[df_1['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_1.loc[markers[i], 'pca_x'], y = df_1.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1'])
plt.show()

# %%
df_1[df_1['pca_y'] > 20] # 편의시설, 교육이 많음

# %%
df_1[df_1['km_cluster'] == 0].describe()

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed_1)      
visualizer.show()

# %%
score = silhouette_score(data_1,df_1['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))

# %% [markdown]
# #### 2.2.3 km_cluster == 2

# %% [markdown]
# - Elbow 관측

# %%
df_2 = df[df['km_cluster'] == 2][tmp_df.columns]
df_2

# %%
col_2 = df_2.columns[6:]
data_2 = df_2[col_2].values

# %%
pca_transformed_2 = pca.fit_transform(data_2)
df_2['pca_x'] = pca_transformed_2[:,0]
df_2['pca_y'] = pca_transformed_2[:,1]
df_2

# %%
inertia = [] # 군집의 centre 와 sample 사이의 거리의 제곱의 합
plt.figure(figsize=(10,6))
for i in range(1, 10): # 군집 개수에 따른 
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, random_state=0)
    kmeans.fit(pca_transformed_2)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 10), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - 2차 k-means : n_cluster = 2(Elbow)로 설정

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, random_state=0)
# label
label_2 = kmeans.fit(pca_transformed_2)
# Getting unique labels
u_labels = np.unique(label_2)

# %%
df_2['km_cluster'] = kmeans.labels_
df_2.groupby('km_cluster').count()

# %%
df_2['pca_x'] = pca_transformed_2[:,0]
df_2['pca_y'] = pca_transformed_2[:,1]

# 클러스터별 인덱스 추출
marker_n = len(df_2['km_cluster'].unique())
markers = []
for i in range(marker_n):
    marker = df_2[df_2['km_cluster'] == i].index
    markers.append(marker)

m = ['o','s','^','v','>']
for i in range(marker_n):
    plt.scatter(x = df_2.loc[markers[i], 'pca_x'], y = df_2.loc[markers[i], 'pca_y'], marker = m[i])

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Clusters Visualization by 2 PCA Components')
plt.legend(['cluster0', 'cluster1','cluster2','cluster3'])
plt.show()

# %%
df_2[df_2['pca_x'] > 8000] # 편의시설의 수가 적고, MZ 세대 수가 많음

# %%
df_2[df_2['km_cluster'] == 0].describe()

# %%
df_2[df_2['pca_y'] > 6] # 동물병원 수가 많음

# %%
df_2[df_2['km_cluster'] == 0].describe()

# %%
# visualizer 생성
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
# 생성 된 visualizer에 데이터 입력 
visualizer.fit(pca_transformed_2)      
visualizer.show()

# %%
score = silhouette_score(data_2,df_2['km_cluster'])
print('Silhouette Score : {0: .3f}'.format(score))
