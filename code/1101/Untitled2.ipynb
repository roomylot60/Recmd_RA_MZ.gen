# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('1101_대형마트_추가.csv')
df
# Out:
#      index   GU   DONG   DONG_CODE  SUBWAY_NUM  STARBUCKS_NUM  SPORT_NUM  \
# 0        0  종로구  청운효자동  1111051500    0.333333       0.333333        0.0
# 1        1  종로구    사직동  1111053000    1.333333       7.333333        0.0
# 2        2  종로구    삼청동  1111054000    1.000000       1.000000        1.0
# 3        3  종로구    부암동  1111055000    0.000000       0.000000        0.0
# 4        4  종로구    평창동  1111056000    0.000000       1.000000        0.0
# ..     ...  ...    ...         ...         ...            ...        ...
# 421    421  강동구   성내2동  1174065000    0.333333       1.333333        0.0
# 422    422  강동구   성내3동  1174066000    0.333333       1.333333        0.0
# 423    423  강동구     길동  1174068500    1.000000       2.000000        0.0
# 424    424  강동구   둔촌1동  1174069000    0.500000       0.000000        0.0
# 425    425  강동구   둔촌2동  1174070000    0.500000       0.000000        0.0
#
#      SAFE_DLVR_NUM  POLICE_NUM  PHARM_NUM  ...    CON_NUM  CHILD_MED_NUM  \
# ...
